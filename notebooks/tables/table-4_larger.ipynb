# %%
import pandas as pd
from tableone import TableOne

from cleaning.caregivers.main import load_data
from notebooks.tables.ref import columns, nonnormal

df = load_data()

df_survived = df[~df["HOSPITAL_EXPIRE_FLAG"]]


annotation_child = TableOne(
    df_survived,
    columns = columns,
    groupby = "ANNOTATION_CHILD",
    nonnormal = nonnormal,
    pval = True
)

annotation_spouse = TableOne(
    df_survived,
    columns = columns,
    groupby = "ANNOTATION_SPOUSE",
    nonnormal = nonnormal,
    pval = True
)

annotation_both = TableOne(
    df_survived,
    columns = columns,
    groupby = "ANNOTATION_BOTH",
    nonnormal = nonnormal,
    pval = True
)

annotation_any = TableOne(
    df_survived,
    columns = columns,
    groupby = "ANNOTATION_ANY",
    nonnormal = nonnormal,
    pval = True
)


table = pd.concat([
    annotation_child.tableone,
    annotation_spouse.tableone,
    annotation_both.tableone,
    annotation_any.tableone
], axis=1)

# %% [markdown]
# # Table 4
#
# Includes only those who survived to discharge

# %%
table
# Out:
#                                                              Grouped by ANNOTATION_CHILD  \
#                                                                                  Missing
# n
# SEX, n (%)                           F                                                 0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                          28
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                              0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                          0
# LOS_HADM, median [Q1,Q3]                                                               0
# DISCHARGE_LOCATION, n (%)            HOME                                              0
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                             0
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                             0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                             0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                             0
#                                      True
# HAS_READMISSION, n (%)               False                                             0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                             0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                             0
#                                      True
# SOFA, median [Q1,Q3]                                                                   0
# ELIX_SCORE, median [Q1,Q3]                                                             0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1046
# SEX, n (%)                           F                              515 (49.2)
#                                      M                              531 (50.8)
# MARITAL_STATUS, n (%)                MARRIED                        423 (41.6)
#                                      NOT MARRIED                    595 (58.4)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           785 (75.0)
#                                      OTHER                          220 (21.0)
#                                      UNKNOWN/NOT SPECIFIED            41 (3.9)
# ADMISSION_AGE, median [Q1,Q3]                                 63.1 [52.6,76.4]
# LOS_HADM, median [Q1,Q3]                                        9.4 [5.5,17.2]
# DISCHARGE_LOCATION, n (%)            HOME                           169 (16.2)
#                                      HOME HEALTH CARE               222 (21.2)
#                                      HOSPICE                          30 (2.9)
#                                      LONG TERM CARE HOSPITAL        249 (23.8)
#                                      OTHER                            70 (6.7)
#                                      SNF                            306 (29.3)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                        1046 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          899 (85.9)
#                                      True                           147 (14.1)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (71.5)
#                                      True                           298 (28.5)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (78.7)
#                                      True                           223 (21.3)
# HAS_READMISSION, n (%)               False                          687 (65.7)
#                                      True                           359 (34.3)
# IDENTIFIED_CONV_GOC, n (%)           False                          397 (38.0)
#                                      True                           649 (62.0)
# IDENTIFIED_CONV_LIM, n (%)           False                          863 (82.5)
#                                      True                           183 (17.5)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          682
# SEX, n (%)                           F                              291 (42.7)
#                                      M                              391 (57.3)
# MARITAL_STATUS, n (%)                MARRIED                        279 (41.9)
#                                      NOT MARRIED                    387 (58.1)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           524 (76.8)
#                                      OTHER                          126 (18.5)
#                                      UNKNOWN/NOT SPECIFIED            32 (4.7)
# ADMISSION_AGE, median [Q1,Q3]                                 58.3 [47.7,69.3]
# LOS_HADM, median [Q1,Q3]                                        9.7 [5.5,18.8]
# DISCHARGE_LOCATION, n (%)            HOME                           129 (18.9)
#                                      HOME HEALTH CARE               142 (20.8)
#                                      HOSPICE                          21 (3.1)
#                                      LONG TERM CARE HOSPITAL        150 (22.0)
#                                      OTHER                            60 (8.8)
#                                      SNF                            180 (26.4)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         682 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          599 (87.8)
#                                      True                            83 (12.2)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          510 (74.8)
#                                      True                           172 (25.2)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          550 (80.6)
#                                      True                           132 (19.4)
# HAS_READMISSION, n (%)               False                          456 (66.9)
#                                      True                           226 (33.1)
# IDENTIFIED_CONV_GOC, n (%)           False                          288 (42.2)
#                                      True                           394 (57.8)
# IDENTIFIED_CONV_LIM, n (%)           False                          602 (88.3)
#                                      True                            80 (11.7)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          364
# SEX, n (%)                           F                              224 (61.5)
#                                      M                              140 (38.5)
# MARITAL_STATUS, n (%)                MARRIED                        144 (40.9)
#                                      NOT MARRIED                    208 (59.1)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           261 (71.7)
#                                      OTHER                           94 (25.8)
#                                      UNKNOWN/NOT SPECIFIED             9 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                 74.4 [62.1,83.1]
# LOS_HADM, median [Q1,Q3]                                        9.0 [5.7,15.1]
# DISCHARGE_LOCATION, n (%)            HOME                            40 (11.0)
#                                      HOME HEALTH CARE                80 (22.0)
#                                      HOSPICE                           9 (2.5)
#                                      LONG TERM CARE HOSPITAL         99 (27.2)
#                                      OTHER                            10 (2.7)
#                                      SNF                            126 (34.6)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         364 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          300 (82.4)
#                                      True                            64 (17.6)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          238 (65.4)
#                                      True                           126 (34.6)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          273 (75.0)
#                                      True                            91 (25.0)
# HAS_READMISSION, n (%)               False                          231 (63.5)
#                                      True                           133 (36.5)
# IDENTIFIED_CONV_GOC, n (%)           False                          109 (29.9)
#                                      True                           255 (70.1)
# IDENTIFIED_CONV_LIM, n (%)           False                          261 (71.7)
#                                      True                           103 (28.3)
# SOFA, median [Q1,Q3]                                             5.0 [4.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       5.0 [3.0,6.0]
#
#                                                                       \
#                                                              P-Value
# n
# SEX, n (%)                           F                        <0.001
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                   0.814
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE      0.007
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                 <0.001
# LOS_HADM, median [Q1,Q3]                                       0.192
# DISCHARGE_LOCATION, n (%)            HOME                     <0.001
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                     1.000
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                     0.021
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                     0.002
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                     0.041
#                                      True
# HAS_READMISSION, n (%)               False                     0.301
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                    <0.001
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                    <0.001
#                                      True
# SOFA, median [Q1,Q3]                                           0.009
# ELIX_SCORE, median [Q1,Q3]                                     0.001
#
#                                                              Grouped by ANNOTATION_SPOUSE  \
#                                                                                   Missing
# n
# SEX, n (%)                           F                                                  0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                           28
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                               0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                           0
# LOS_HADM, median [Q1,Q3]                                                                0
# DISCHARGE_LOCATION, n (%)            HOME                                               0
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                              0
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                              0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                              0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                              0
#                                      True
# HAS_READMISSION, n (%)               False                                              0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                              0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                              0
#                                      True
# SOFA, median [Q1,Q3]                                                                    0
# ELIX_SCORE, median [Q1,Q3]                                                              0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1046
# SEX, n (%)                           F                              515 (49.2)
#                                      M                              531 (50.8)
# MARITAL_STATUS, n (%)                MARRIED                        423 (41.6)
#                                      NOT MARRIED                    595 (58.4)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           785 (75.0)
#                                      OTHER                          220 (21.0)
#                                      UNKNOWN/NOT SPECIFIED            41 (3.9)
# ADMISSION_AGE, median [Q1,Q3]                                 63.1 [52.6,76.4]
# LOS_HADM, median [Q1,Q3]                                        9.4 [5.5,17.2]
# DISCHARGE_LOCATION, n (%)            HOME                           169 (16.2)
#                                      HOME HEALTH CARE               222 (21.2)
#                                      HOSPICE                          30 (2.9)
#                                      LONG TERM CARE HOSPITAL        249 (23.8)
#                                      OTHER                            70 (6.7)
#                                      SNF                            306 (29.3)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                        1046 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          899 (85.9)
#                                      True                           147 (14.1)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (71.5)
#                                      True                           298 (28.5)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (78.7)
#                                      True                           223 (21.3)
# HAS_READMISSION, n (%)               False                          687 (65.7)
#                                      True                           359 (34.3)
# IDENTIFIED_CONV_GOC, n (%)           False                          397 (38.0)
#                                      True                           649 (62.0)
# IDENTIFIED_CONV_LIM, n (%)           False                          863 (82.5)
#                                      True                           183 (17.5)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          684
# SEX, n (%)                           F                              369 (53.9)
#                                      M                              315 (46.1)
# MARITAL_STATUS, n (%)                MARRIED                        139 (21.0)
#                                      NOT MARRIED                    523 (79.0)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           491 (71.8)
#                                      OTHER                          170 (24.9)
#                                      UNKNOWN/NOT SPECIFIED            23 (3.4)
# ADMISSION_AGE, median [Q1,Q3]                                 63.9 [52.7,78.3]
# LOS_HADM, median [Q1,Q3]                                        8.8 [5.1,16.7]
# DISCHARGE_LOCATION, n (%)            HOME                           101 (14.8)
#                                      HOME HEALTH CARE               151 (22.1)
#                                      HOSPICE                          16 (2.3)
#                                      LONG TERM CARE HOSPITAL        161 (23.5)
#                                      OTHER                            46 (6.7)
#                                      SNF                            209 (30.6)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         684 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          589 (86.1)
#                                      True                            95 (13.9)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          486 (71.1)
#                                      True                           198 (28.9)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          541 (79.1)
#                                      True                           143 (20.9)
# HAS_READMISSION, n (%)               False                          431 (63.0)
#                                      True                           253 (37.0)
# IDENTIFIED_CONV_GOC, n (%)           False                          290 (42.4)
#                                      True                           394 (57.6)
# IDENTIFIED_CONV_LIM, n (%)           False                          551 (80.6)
#                                      True                           133 (19.4)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          362
# SEX, n (%)                           F                              146 (40.3)
#                                      M                              216 (59.7)
# MARITAL_STATUS, n (%)                MARRIED                        284 (79.8)
#                                      NOT MARRIED                     72 (20.2)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           294 (81.2)
#                                      OTHER                           50 (13.8)
#                                      UNKNOWN/NOT SPECIFIED            18 (5.0)
# ADMISSION_AGE, median [Q1,Q3]                                 61.8 [51.9,71.0]
# LOS_HADM, median [Q1,Q3]                                       11.5 [6.3,18.6]
# DISCHARGE_LOCATION, n (%)            HOME                            68 (18.8)
#                                      HOME HEALTH CARE                71 (19.6)
#                                      HOSPICE                          14 (3.9)
#                                      LONG TERM CARE HOSPITAL         88 (24.3)
#                                      OTHER                            24 (6.6)
#                                      SNF                             97 (26.8)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         362 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          310 (85.6)
#                                      True                            52 (14.4)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          262 (72.4)
#                                      True                           100 (27.6)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          282 (77.9)
#                                      True                            80 (22.1)
# HAS_READMISSION, n (%)               False                          256 (70.7)
#                                      True                           106 (29.3)
# IDENTIFIED_CONV_GOC, n (%)           False                          107 (29.6)
#                                      True                           255 (70.4)
# IDENTIFIED_CONV_LIM, n (%)           False                          312 (86.2)
#                                      True                            50 (13.8)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                       \
#                                                              P-Value
# n
# SEX, n (%)                           F                        <0.001
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                  <0.001
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE     <0.001
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                  0.003
# LOS_HADM, median [Q1,Q3]                                       0.001
# DISCHARGE_LOCATION, n (%)            HOME                      0.289
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                     1.000
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                     0.907
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                     0.705
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                     0.712
#                                      True
# HAS_READMISSION, n (%)               False                     0.015
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                    <0.001
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                     0.028
#                                      True
# SOFA, median [Q1,Q3]                                           0.042
# ELIX_SCORE, median [Q1,Q3]                                     0.716
#
#                                                              Grouped by ANNOTATION_BOTH  \
#                                                                                 Missing
# n
# SEX, n (%)                           F                                                0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                         28
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                             0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                         0
# LOS_HADM, median [Q1,Q3]                                                              0
# DISCHARGE_LOCATION, n (%)            HOME                                             0
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                            0
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                            0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                            0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                            0
#                                      True
# HAS_READMISSION, n (%)               False                                            0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                            0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                            0
#                                      True
# SOFA, median [Q1,Q3]                                                                  0
# ELIX_SCORE, median [Q1,Q3]                                                            0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1046
# SEX, n (%)                           F                              515 (49.2)
#                                      M                              531 (50.8)
# MARITAL_STATUS, n (%)                MARRIED                        423 (41.6)
#                                      NOT MARRIED                    595 (58.4)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           785 (75.0)
#                                      OTHER                          220 (21.0)
#                                      UNKNOWN/NOT SPECIFIED            41 (3.9)
# ADMISSION_AGE, median [Q1,Q3]                                 63.1 [52.6,76.4]
# LOS_HADM, median [Q1,Q3]                                        9.4 [5.5,17.2]
# DISCHARGE_LOCATION, n (%)            HOME                           169 (16.2)
#                                      HOME HEALTH CARE               222 (21.2)
#                                      HOSPICE                          30 (2.9)
#                                      LONG TERM CARE HOSPITAL        249 (23.8)
#                                      OTHER                            70 (6.7)
#                                      SNF                            306 (29.3)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                        1046 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          899 (85.9)
#                                      True                           147 (14.1)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (71.5)
#                                      True                           298 (28.5)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (78.7)
#                                      True                           223 (21.3)
# HAS_READMISSION, n (%)               False                          687 (65.7)
#                                      True                           359 (34.3)
# IDENTIFIED_CONV_GOC, n (%)           False                          397 (38.0)
#                                      True                           649 (62.0)
# IDENTIFIED_CONV_LIM, n (%)           False                          863 (82.5)
#                                      True                           183 (17.5)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          925
# SEX, n (%)                           F                              459 (49.6)
#                                      M                              466 (50.4)
# MARITAL_STATUS, n (%)                MARRIED                        324 (36.0)
#                                      NOT MARRIED                    575 (64.0)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           688 (74.4)
#                                      OTHER                          199 (21.5)
#                                      UNKNOWN/NOT SPECIFIED            38 (4.1)
# ADMISSION_AGE, median [Q1,Q3]                                 62.1 [51.8,76.1]
# LOS_HADM, median [Q1,Q3]                                        9.1 [5.3,17.2]
# DISCHARGE_LOCATION, n (%)            HOME                           158 (17.1)
#                                      HOME HEALTH CARE               197 (21.3)
#                                      HOSPICE                          25 (2.7)
#                                      LONG TERM CARE HOSPITAL        209 (22.6)
#                                      OTHER                            65 (7.0)
#                                      SNF                            271 (29.3)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         925 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          799 (86.4)
#                                      True                           126 (13.6)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          664 (71.8)
#                                      True                           261 (28.2)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          729 (78.8)
#                                      True                           196 (21.2)
# HAS_READMISSION, n (%)               False                          609 (65.8)
#                                      True                           316 (34.2)
# IDENTIFIED_CONV_GOC, n (%)           False                          362 (39.1)
#                                      True                           563 (60.9)
# IDENTIFIED_CONV_LIM, n (%)           False                          767 (82.9)
#                                      True                           158 (17.1)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          121
# SEX, n (%)                           F                               56 (46.3)
#                                      M                               65 (53.7)
# MARITAL_STATUS, n (%)                MARRIED                         99 (83.2)
#                                      NOT MARRIED                     20 (16.8)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE            97 (80.2)
#                                      OTHER                           21 (17.4)
#                                      UNKNOWN/NOT SPECIFIED             3 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                 68.2 [60.8,77.4]
# LOS_HADM, median [Q1,Q3]                                       10.6 [6.2,17.3]
# DISCHARGE_LOCATION, n (%)            HOME                             11 (9.1)
#                                      HOME HEALTH CARE                25 (20.7)
#                                      HOSPICE                           5 (4.1)
#                                      LONG TERM CARE HOSPITAL         40 (33.1)
#                                      OTHER                             5 (4.1)
#                                      SNF                             35 (28.9)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         121 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          100 (82.6)
#                                      True                            21 (17.4)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                           84 (69.4)
#                                      True                            37 (30.6)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                           94 (77.7)
#                                      True                            27 (22.3)
# HAS_READMISSION, n (%)               False                           78 (64.5)
#                                      True                            43 (35.5)
# IDENTIFIED_CONV_GOC, n (%)           False                           35 (28.9)
#                                      True                            86 (71.1)
# IDENTIFIED_CONV_LIM, n (%)           False                           96 (79.3)
#                                      True                            25 (20.7)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       5.0 [3.0,6.0]
#
#                                                                       \
#                                                              P-Value
# n
# SEX, n (%)                           F                         0.552
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                  <0.001
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE      0.353
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                 <0.001
# LOS_HADM, median [Q1,Q3]                                       0.287
# DISCHARGE_LOCATION, n (%)            HOME                      0.046
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                     1.000
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                     0.331
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                     0.664
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                     0.868
#                                      True
# HAS_READMISSION, n (%)               False                     0.843
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                     0.038
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                     0.397
#                                      True
# SOFA, median [Q1,Q3]                                           0.002
# ELIX_SCORE, median [Q1,Q3]                                     0.074
#
#                                                              Grouped by ANNOTATION_ANY  \
#                                                                                Missing
# n
# SEX, n (%)                           F                                               0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                        28
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                            0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                        0
# LOS_HADM, median [Q1,Q3]                                                             0
# DISCHARGE_LOCATION, n (%)            HOME                                            0
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                           0
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                           0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                           0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                           0
#                                      True
# HAS_READMISSION, n (%)               False                                           0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                           0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                           0
#                                      True
# SOFA, median [Q1,Q3]                                                                 0
# ELIX_SCORE, median [Q1,Q3]                                                           0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1046
# SEX, n (%)                           F                              515 (49.2)
#                                      M                              531 (50.8)
# MARITAL_STATUS, n (%)                MARRIED                        423 (41.6)
#                                      NOT MARRIED                    595 (58.4)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           785 (75.0)
#                                      OTHER                          220 (21.0)
#                                      UNKNOWN/NOT SPECIFIED            41 (3.9)
# ADMISSION_AGE, median [Q1,Q3]                                 63.1 [52.6,76.4]
# LOS_HADM, median [Q1,Q3]                                        9.4 [5.5,17.2]
# DISCHARGE_LOCATION, n (%)            HOME                           169 (16.2)
#                                      HOME HEALTH CARE               222 (21.2)
#                                      HOSPICE                          30 (2.9)
#                                      LONG TERM CARE HOSPITAL        249 (23.8)
#                                      OTHER                            70 (6.7)
#                                      SNF                            306 (29.3)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                        1046 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          899 (85.9)
#                                      True                           147 (14.1)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (71.5)
#                                      True                           298 (28.5)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (78.7)
#                                      True                           223 (21.3)
# HAS_READMISSION, n (%)               False                          687 (65.7)
#                                      True                           359 (34.3)
# IDENTIFIED_CONV_GOC, n (%)           False                          397 (38.0)
#                                      True                           649 (62.0)
# IDENTIFIED_CONV_LIM, n (%)           False                          863 (82.5)
#                                      True                           183 (17.5)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          441
# SEX, n (%)                           F                              201 (45.6)
#                                      M                              240 (54.4)
# MARITAL_STATUS, n (%)                MARRIED                         94 (21.9)
#                                      NOT MARRIED                    335 (78.1)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           327 (74.1)
#                                      OTHER                           97 (22.0)
#                                      UNKNOWN/NOT SPECIFIED            17 (3.9)
# ADMISSION_AGE, median [Q1,Q3]                                 58.2 [47.4,71.3]
# LOS_HADM, median [Q1,Q3]                                        8.8 [5.0,17.9]
# DISCHARGE_LOCATION, n (%)            HOME                            72 (16.3)
#                                      HOME HEALTH CARE                96 (21.8)
#                                      HOSPICE                          12 (2.7)
#                                      LONG TERM CARE HOSPITAL        102 (23.1)
#                                      OTHER                            41 (9.3)
#                                      SNF                            118 (26.8)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         441 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          389 (88.2)
#                                      True                            52 (11.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          332 (75.3)
#                                      True                           109 (24.7)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          362 (82.1)
#                                      True                            79 (17.9)
# HAS_READMISSION, n (%)               False                          278 (63.0)
#                                      True                           163 (37.0)
# IDENTIFIED_CONV_GOC, n (%)           False                          216 (49.0)
#                                      True                           225 (51.0)
# IDENTIFIED_CONV_LIM, n (%)           False                          386 (87.5)
#                                      True                            55 (12.5)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,7.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          605
# SEX, n (%)                           F                              314 (51.9)
#                                      M                              291 (48.1)
# MARITAL_STATUS, n (%)                MARRIED                        329 (55.9)
#                                      NOT MARRIED                    260 (44.1)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           458 (75.7)
#                                      OTHER                          123 (20.3)
#                                      UNKNOWN/NOT SPECIFIED            24 (4.0)
# ADMISSION_AGE, median [Q1,Q3]                                 66.6 [55.1,78.5]
# LOS_HADM, median [Q1,Q3]                                        9.7 [5.9,16.9]
# DISCHARGE_LOCATION, n (%)            HOME                            97 (16.0)
#                                      HOME HEALTH CARE               126 (20.8)
#                                      HOSPICE                          18 (3.0)
#                                      LONG TERM CARE HOSPITAL        147 (24.3)
#                                      OTHER                            29 (4.8)
#                                      SNF                            188 (31.1)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         605 (100.0)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          510 (84.3)
#                                      True                            95 (15.7)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          416 (68.8)
#                                      True                           189 (31.2)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          461 (76.2)
#                                      True                           144 (23.8)
# HAS_READMISSION, n (%)               False                          409 (67.6)
#                                      True                           196 (32.4)
# IDENTIFIED_CONV_GOC, n (%)           False                          181 (29.9)
#                                      True                           424 (70.1)
# IDENTIFIED_CONV_LIM, n (%)           False                          477 (78.8)
#                                      True                           128 (21.2)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#
#                                                              P-Value
# n
# SEX, n (%)                           F                         0.050
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                  <0.001
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE      0.808
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                 <0.001
# LOS_HADM, median [Q1,Q3]                                       0.256
# DISCHARGE_LOCATION, n (%)            HOME                      0.085
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                     1.000
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                     0.088
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                     0.025
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                     0.026
#                                      True
# HAS_READMISSION, n (%)               False                     0.142
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                    <0.001
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                    <0.001
#                                      True
# SOFA, median [Q1,Q3]                                           0.014
# ELIX_SCORE, median [Q1,Q3]                                     0.013
