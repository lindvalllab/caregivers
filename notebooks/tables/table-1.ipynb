# %%
import pandas as pd
from tableone import TableOne

from cleaning.caregivers.main import load_data
from notebooks.tables.ref import columns, nonnormal

df = load_data()

table = TableOne(
    df,
    columns = columns,
    nonnormal = nonnormal
)

# %% [markdown]
# # Table 1
# Total study population characteristics

# %%
table
# Out:
#                                                              Missing            Overall
# n                                                                                  1389
# SEX, n (%)                           F                             0         666 (47.9)
#                                      M                                       723 (52.1)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED           47          119 (8.9)
#                                      MARRIED                                 595 (44.3)
#                                      SINGLE                                  438 (32.6)
#                                      WIDOWED                                 190 (14.2)
# ETHNICITY, n (%)                     ASIAN                         0           40 (2.9)
#                                      BLACK                                   160 (11.5)
#                                      HISPANIC/LATINO                           53 (3.8)
#                                      OTHER                                     30 (2.2)
#                                      UNKNOWN/NOT SPECIFIED                     71 (5.1)
#                                      WHITE                                  1035 (74.5)
# LANGUAGE, n (%)                      ENGL                          0        1207 (86.9)
#                                      OTHER                                     73 (5.3)
#                                      PTUN                                      40 (2.9)
#                                      RUSS                                      34 (2.4)
#                                      SPAN                                      35 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                      0   64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                           0     9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                  0         343 (24.7)
#                                      HOME                                    169 (12.2)
#                                      HOME HEALTH CARE                        222 (16.0)
#                                      HOSPICE                                   30 (2.2)
#                                      LONG TERM CARE HOSPITAL                 249 (17.9)
#                                      OTHER                                     70 (5.0)
#                                      SNF                                     306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         0        1046 (75.3)
#                                      True                                    343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                         0         905 (65.2)
#                                      True                                    484 (34.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                         0         748 (53.9)
#                                      True                                    641 (46.1)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                         0         823 (59.3)
#                                      True                                    566 (40.7)
# HAS_READMISSION, n (%)               False                         0        1030 (74.2)
#                                      True                                    359 (25.8)
# IDENTIFIED_CONV_GOC, n (%)           False                         0         443 (31.9)
#                                      True                                    946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                         0        1026 (73.9)
#                                      True                                    363 (26.1)
# SOFA, median [Q1,Q3]                                               0      6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                         0      4.0 [3.0,6.0]
# ELIX_WEIGHTED_AHRQ, median [Q1,Q3]                                 0    15.0 [8.0,24.0]
# ELIX_WEIGHTED_VW, median [Q1,Q3]                                   0    14.0 [7.0,20.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                   0  42.6 [13.7,134.5]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                   0      1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                         0         307 (22.1)
#                                      True                                   1082 (77.9)
# VENT_FIRST_48_ICU, n (%)             False                         0          125 (9.0)
#                                      True                                   1264 (91.0)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                0     4.2 [1.5,37.8]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                64      1.9 [0.6,6.0]
