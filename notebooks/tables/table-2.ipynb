# %%
import pandas as pd
from tableone import TableOne

from cleaning.caregivers.main import load_data
from notebooks.tables.ref import columns, nonnormal

df = load_data()


annotation_child = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_CHILD",
    nonnormal = nonnormal
)

annotation_spouse = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_SPOUSE",
    nonnormal = nonnormal
)

annotation_both = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_BOTH",
    nonnormal = nonnormal
)

annotation_any = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_ANY",
    nonnormal = nonnormal
)


table = pd.concat([
    annotation_child.tableone,
    annotation_spouse.tableone,
    annotation_both.tableone,
    annotation_any.tableone
], axis=1)

# %% [markdown]
# # Table 2
# Study population stratified by child, spouse, and both (unadjusted)

# %%
table
# Out:
#                                                                    Grouped by ANNOTATION_CHILD  \
#                                                                                        Missing
# n
# SEX, n (%)                           F                                                       0
#                                      M
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                                     47
#                                      MARRIED
#                                      SINGLE
#                                      WIDOWED
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE                           0
#                                      ASIAN
#                                      BLACK/AFRICAN AMERICAN
#                                      HISPANIC/LATINO
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
#                                      WHITE
# LANGUAGE, n (%)                      ENGL                                                    0
#                                      OTHER
#                                      PTUN
#                                      RUSS
#                                      SPAN
# ADMISSION_AGE, median [Q1,Q3]                                                                0
# LOS_HADM, median [Q1,Q3]                                                                     0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                            0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                                   0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                                 582
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                                 582
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                                 582
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                                   0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                                   0
#                                      True
# SOFA, median [Q1,Q3]                                                                         0
# VENT_TOTAL_HOURS, median [Q1,Q3]                                                             0
# VENT_TOTAL_COUNT, median [Q1,Q3]                                                             0
# VENT_FIRST_48_HADM, n (%)            False                                                   0
#                                      True
# VENT_FIRST_48_ICU, n (%)             False                                                   0
#                                      True
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                                          0
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                                           0
#
#                                                                                        \
#                                                                               Overall
# n                                                                                1389
# SEX, n (%)                           F                                     666 (47.9)
#                                      M                                     723 (52.1)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     119 (8.9)
#                                      MARRIED                               595 (44.3)
#                                      SINGLE                                438 (32.6)
#                                      WIDOWED                               190 (14.2)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   40 (2.9)
#                                      BLACK/AFRICAN AMERICAN                160 (11.5)
#                                      HISPANIC/LATINO                         53 (3.8)
#                                      OTHER                                   29 (2.1)
#                                      UNKNOWN/NOT SPECIFIED                   71 (5.1)
#                                      WHITE                                1035 (74.5)
# LANGUAGE, n (%)                      ENGL                                 1207 (86.9)
#                                      OTHER                                   73 (5.3)
#                                      PTUN                                    40 (2.9)
#                                      RUSS                                    34 (2.4)
#                                      SPAN                                    35 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                        64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                               9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          343 (24.7)
#                                      HOME                                  169 (12.2)
#                                      HOME HEALTH CARE                      222 (16.0)
#                                      HOSPICE                                 30 (2.2)
#                                      LONG TERM CARE HOSPITAL               249 (17.9)
#                                      OTHER                                   70 (5.0)
#                                      SNF                                   306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                1046 (75.3)
#                                      True                                  343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 323 (40.0)
#                                      True                                  484 (60.0)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                 166 (20.6)
#                                      True                                  641 (79.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 242 (30.0)
#                                      True                                  565 (70.0)
# IDENTIFIED_CONV_GOC, n (%)           False                                 443 (31.9)
#                                      True                                  946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                                1026 (73.9)
#                                      True                                  363 (26.1)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,9.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    42.6 [13.7,134.5]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 307 (22.1)
#                                      True                                 1082 (77.9)
# VENT_FIRST_48_ICU, n (%)             False                                   66 (4.8)
#                                      True                                 1323 (95.2)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.2 [1.5,37.8]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.6,6.2]
#
#                                                                                        \
#                                                                                 False
# n                                                                                 835
# SEX, n (%)                           F                                     352 (42.2)
#                                      M                                     483 (57.8)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                      55 (6.8)
#                                      MARRIED                               353 (43.7)
#                                      SINGLE                                346 (42.8)
#                                      WIDOWED                                 54 (6.7)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   16 (1.9)
#                                      BLACK/AFRICAN AMERICAN                 95 (11.4)
#                                      HISPANIC/LATINO                         30 (3.6)
#                                      OTHER                                   17 (2.0)
#                                      UNKNOWN/NOT SPECIFIED                   46 (5.5)
#                                      WHITE                                 630 (75.4)
# LANGUAGE, n (%)                      ENGL                                  764 (91.5)
#                                      OTHER                                   26 (3.1)
#                                      PTUN                                    19 (2.3)
#                                      RUSS                                    10 (1.2)
#                                      SPAN                                    16 (1.9)
# ADMISSION_AGE, median [Q1,Q3]                                        58.8 [47.9,69.5]
# LOS_HADM, median [Q1,Q3]                                               9.6 [5.0,18.9]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          153 (18.3)
#                                      HOME                                  129 (15.4)
#                                      HOME HEALTH CARE                      142 (17.0)
#                                      HOSPICE                                 21 (2.5)
#                                      LONG TERM CARE HOSPITAL               150 (18.0)
#                                      OTHER                                   60 (7.2)
#                                      SNF                                   180 (21.6)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                 682 (81.7)
#                                      True                                  153 (18.3)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 181 (43.6)
#                                      True                                  234 (56.4)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                  90 (21.7)
#                                      True                                  325 (78.3)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 131 (31.6)
#                                      True                                  284 (68.4)
# IDENTIFIED_CONV_GOC, n (%)           False                                 319 (38.2)
#                                      True                                  516 (61.8)
# IDENTIFIED_CONV_LIM, n (%)           False                                 694 (83.1)
#                                      True                                  141 (16.9)
# SOFA, median [Q1,Q3]                                                    5.0 [3.0,8.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    42.4 [13.7,154.9]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 192 (23.0)
#                                      True                                  643 (77.0)
# VENT_FIRST_48_ICU, n (%)             False                                   43 (5.1)
#                                      True                                  792 (94.9)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.7 [1.5,41.3]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.6,6.5]
#
#                                                                                        \
#                                                                                  True
# n                                                                                 554
# SEX, n (%)                           F                                     314 (56.7)
#                                      M                                     240 (43.3)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     64 (12.0)
#                                      MARRIED                               242 (45.3)
#                                      SINGLE                                 92 (17.2)
#                                      WIDOWED                               136 (25.5)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE
#                                      ASIAN                                   24 (4.3)
#                                      BLACK/AFRICAN AMERICAN                 65 (11.7)
#                                      HISPANIC/LATINO                         23 (4.2)
#                                      OTHER                                   12 (2.2)
#                                      UNKNOWN/NOT SPECIFIED                   25 (4.5)
#                                      WHITE                                 405 (73.1)
# LANGUAGE, n (%)                      ENGL                                  443 (80.0)
#                                      OTHER                                   47 (8.5)
#                                      PTUN                                    21 (3.8)
#                                      RUSS                                    24 (4.3)
#                                      SPAN                                    19 (3.4)
# ADMISSION_AGE, median [Q1,Q3]                                        74.5 [63.2,83.1]
# LOS_HADM, median [Q1,Q3]                                               8.1 [4.7,15.4]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          190 (34.3)
#                                      HOME                                    40 (7.2)
#                                      HOME HEALTH CARE                       80 (14.4)
#                                      HOSPICE                                  9 (1.6)
#                                      LONG TERM CARE HOSPITAL                99 (17.9)
#                                      OTHER                                   10 (1.8)
#                                      SNF                                   126 (22.7)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                 364 (65.7)
#                                      True                                  190 (34.3)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 142 (36.2)
#                                      True                                  250 (63.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                  76 (19.4)
#                                      True                                  316 (80.6)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 111 (28.3)
#                                      True                                  281 (71.7)
# IDENTIFIED_CONV_GOC, n (%)           False                                 124 (22.4)
#                                      True                                  430 (77.6)
# IDENTIFIED_CONV_LIM, n (%)           False                                 332 (59.9)
#                                      True                                  222 (40.1)
# SOFA, median [Q1,Q3]                                                   6.0 [4.0,10.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    43.2 [14.0,117.2]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 115 (20.8)
#                                      True                                  439 (79.2)
# VENT_FIRST_48_ICU, n (%)             False                                   23 (4.2)
#                                      True                                  531 (95.8)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    3.7 [1.6,32.2]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.6,5.8]
#
#                                                                    Grouped by ANNOTATION_SPOUSE  \
#                                                                                         Missing
# n
# SEX, n (%)                           F                                                        0
#                                      M
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                                      47
#                                      MARRIED
#                                      SINGLE
#                                      WIDOWED
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE                            0
#                                      ASIAN
#                                      BLACK/AFRICAN AMERICAN
#                                      HISPANIC/LATINO
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
#                                      WHITE
# LANGUAGE, n (%)                      ENGL                                                     0
#                                      OTHER
#                                      PTUN
#                                      RUSS
#                                      SPAN
# ADMISSION_AGE, median [Q1,Q3]                                                                 0
# LOS_HADM, median [Q1,Q3]                                                                      0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                             0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                                    0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                                  582
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                                  582
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                                  582
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                                    0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                                    0
#                                      True
# SOFA, median [Q1,Q3]                                                                          0
# VENT_TOTAL_HOURS, median [Q1,Q3]                                                              0
# VENT_TOTAL_COUNT, median [Q1,Q3]                                                              0
# VENT_FIRST_48_HADM, n (%)            False                                                    0
#                                      True
# VENT_FIRST_48_ICU, n (%)             False                                                    0
#                                      True
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                                           0
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                                            0
#
#                                                                                        \
#                                                                               Overall
# n                                                                                1389
# SEX, n (%)                           F                                     666 (47.9)
#                                      M                                     723 (52.1)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     119 (8.9)
#                                      MARRIED                               595 (44.3)
#                                      SINGLE                                438 (32.6)
#                                      WIDOWED                               190 (14.2)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   40 (2.9)
#                                      BLACK/AFRICAN AMERICAN                160 (11.5)
#                                      HISPANIC/LATINO                         53 (3.8)
#                                      OTHER                                   29 (2.1)
#                                      UNKNOWN/NOT SPECIFIED                   71 (5.1)
#                                      WHITE                                1035 (74.5)
# LANGUAGE, n (%)                      ENGL                                 1207 (86.9)
#                                      OTHER                                   73 (5.3)
#                                      PTUN                                    40 (2.9)
#                                      RUSS                                    34 (2.4)
#                                      SPAN                                    35 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                        64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                               9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          343 (24.7)
#                                      HOME                                  169 (12.2)
#                                      HOME HEALTH CARE                      222 (16.0)
#                                      HOSPICE                                 30 (2.2)
#                                      LONG TERM CARE HOSPITAL               249 (17.9)
#                                      OTHER                                   70 (5.0)
#                                      SNF                                   306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                1046 (75.3)
#                                      True                                  343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 323 (40.0)
#                                      True                                  484 (60.0)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                 166 (20.6)
#                                      True                                  641 (79.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 242 (30.0)
#                                      True                                  565 (70.0)
# IDENTIFIED_CONV_GOC, n (%)           False                                 443 (31.9)
#                                      True                                  946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                                1026 (73.9)
#                                      True                                  363 (26.1)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,9.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    42.6 [13.7,134.5]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 307 (22.1)
#                                      True                                 1082 (77.9)
# VENT_FIRST_48_ICU, n (%)             False                                   66 (4.8)
#                                      True                                 1323 (95.2)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.2 [1.5,37.8]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.6,6.2]
#
#                                                                                        \
#                                                                                 False
# n                                                                                 883
# SEX, n (%)                           F                                     480 (54.4)
#                                      M                                     403 (45.6)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     99 (11.7)
#                                      MARRIED                               188 (22.2)
#                                      SINGLE                                379 (44.8)
#                                      WIDOWED                               180 (21.3)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE
#                                      ASIAN                                   24 (2.7)
#                                      BLACK/AFRICAN AMERICAN                129 (14.6)
#                                      HISPANIC/LATINO                         42 (4.8)
#                                      OTHER                                   18 (2.0)
#                                      UNKNOWN/NOT SPECIFIED                   43 (4.9)
#                                      WHITE                                 627 (71.0)
# LANGUAGE, n (%)                      ENGL                                  765 (86.6)
#                                      OTHER                                   45 (5.1)
#                                      PTUN                                    22 (2.5)
#                                      RUSS                                    25 (2.8)
#                                      SPAN                                    26 (2.9)
# ADMISSION_AGE, median [Q1,Q3]                                        67.0 [53.4,79.5]
# LOS_HADM, median [Q1,Q3]                                               8.5 [4.8,16.5]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          199 (22.5)
#                                      HOME                                  101 (11.4)
#                                      HOME HEALTH CARE                      151 (17.1)
#                                      HOSPICE                                 16 (1.8)
#                                      LONG TERM CARE HOSPITAL               161 (18.2)
#                                      OTHER                                   46 (5.2)
#                                      SNF                                   209 (23.7)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                 684 (77.5)
#                                      True                                  199 (22.5)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 217 (42.5)
#                                      True                                  294 (57.5)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                 114 (22.3)
#                                      True                                  397 (77.7)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 170 (33.3)
#                                      True                                  341 (66.7)
# IDENTIFIED_CONV_GOC, n (%)           False                                 322 (36.5)
#                                      True                                  561 (63.5)
# IDENTIFIED_CONV_LIM, n (%)           False                                 645 (73.0)
#                                      True                                  238 (27.0)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,8.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    36.3 [12.3,116.0]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,1.0]
# VENT_FIRST_48_HADM, n (%)            False                                 179 (20.3)
#                                      True                                  704 (79.7)
# VENT_FIRST_48_ICU, n (%)             False                                   44 (5.0)
#                                      True                                  839 (95.0)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.3 [1.6,30.6]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      2.0 [0.8,6.5]
#
#                                                                                        \
#                                                                                  True
# n                                                                                 506
# SEX, n (%)                           F                                     186 (36.8)
#                                      M                                     320 (63.2)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                      20 (4.0)
#                                      MARRIED                               407 (82.1)
#                                      SINGLE                                 59 (11.9)
#                                      WIDOWED                                 10 (2.0)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.2)
#                                      ASIAN                                   16 (3.2)
#                                      BLACK/AFRICAN AMERICAN                  31 (6.1)
#                                      HISPANIC/LATINO                         11 (2.2)
#                                      OTHER                                   11 (2.2)
#                                      UNKNOWN/NOT SPECIFIED                   28 (5.5)
#                                      WHITE                                 408 (80.6)
# LANGUAGE, n (%)                      ENGL                                  442 (87.4)
#                                      OTHER                                   28 (5.5)
#                                      PTUN                                    18 (3.6)
#                                      RUSS                                     9 (1.8)
#                                      SPAN                                     9 (1.8)
# ADMISSION_AGE, median [Q1,Q3]                                        62.9 [53.2,72.7]
# LOS_HADM, median [Q1,Q3]                                              10.6 [5.4,18.9]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          144 (28.5)
#                                      HOME                                   68 (13.4)
#                                      HOME HEALTH CARE                       71 (14.0)
#                                      HOSPICE                                 14 (2.8)
#                                      LONG TERM CARE HOSPITAL                88 (17.4)
#                                      OTHER                                   24 (4.7)
#                                      SNF                                    97 (19.2)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                 362 (71.5)
#                                      True                                  144 (28.5)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 106 (35.8)
#                                      True                                  190 (64.2)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                  52 (17.6)
#                                      True                                  244 (82.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                  72 (24.3)
#                                      True                                  224 (75.7)
# IDENTIFIED_CONV_GOC, n (%)           False                                 121 (23.9)
#                                      True                                  385 (76.1)
# IDENTIFIED_CONV_LIM, n (%)           False                                 381 (75.3)
#                                      True                                  125 (24.7)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,9.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    59.1 [19.0,169.4]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 128 (25.3)
#                                      True                                  378 (74.7)
# VENT_FIRST_48_ICU, n (%)             False                                   22 (4.3)
#                                      True                                  484 (95.7)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    3.8 [1.4,49.9]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.8 [0.5,5.4]
#
#                                                                    Grouped by ANNOTATION_BOTH  \
#                                                                                       Missing
# n
# SEX, n (%)                           F                                                      0
#                                      M
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                                    47
#                                      MARRIED
#                                      SINGLE
#                                      WIDOWED
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE                          0
#                                      ASIAN
#                                      BLACK/AFRICAN AMERICAN
#                                      HISPANIC/LATINO
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
#                                      WHITE
# LANGUAGE, n (%)                      ENGL                                                   0
#                                      OTHER
#                                      PTUN
#                                      RUSS
#                                      SPAN
# ADMISSION_AGE, median [Q1,Q3]                                                               0
# LOS_HADM, median [Q1,Q3]                                                                    0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                           0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                                  0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                                582
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                                582
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                                582
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                                  0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                                  0
#                                      True
# SOFA, median [Q1,Q3]                                                                        0
# VENT_TOTAL_HOURS, median [Q1,Q3]                                                            0
# VENT_TOTAL_COUNT, median [Q1,Q3]                                                            0
# VENT_FIRST_48_HADM, n (%)            False                                                  0
#                                      True
# VENT_FIRST_48_ICU, n (%)             False                                                  0
#                                      True
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                                         0
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                                          0
#
#                                                                                        \
#                                                                               Overall
# n                                                                                1389
# SEX, n (%)                           F                                     666 (47.9)
#                                      M                                     723 (52.1)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     119 (8.9)
#                                      MARRIED                               595 (44.3)
#                                      SINGLE                                438 (32.6)
#                                      WIDOWED                               190 (14.2)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   40 (2.9)
#                                      BLACK/AFRICAN AMERICAN                160 (11.5)
#                                      HISPANIC/LATINO                         53 (3.8)
#                                      OTHER                                   29 (2.1)
#                                      UNKNOWN/NOT SPECIFIED                   71 (5.1)
#                                      WHITE                                1035 (74.5)
# LANGUAGE, n (%)                      ENGL                                 1207 (86.9)
#                                      OTHER                                   73 (5.3)
#                                      PTUN                                    40 (2.9)
#                                      RUSS                                    34 (2.4)
#                                      SPAN                                    35 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                        64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                               9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          343 (24.7)
#                                      HOME                                  169 (12.2)
#                                      HOME HEALTH CARE                      222 (16.0)
#                                      HOSPICE                                 30 (2.2)
#                                      LONG TERM CARE HOSPITAL               249 (17.9)
#                                      OTHER                                   70 (5.0)
#                                      SNF                                   306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                1046 (75.3)
#                                      True                                  343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 323 (40.0)
#                                      True                                  484 (60.0)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                 166 (20.6)
#                                      True                                  641 (79.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 242 (30.0)
#                                      True                                  565 (70.0)
# IDENTIFIED_CONV_GOC, n (%)           False                                 443 (31.9)
#                                      True                                  946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                                1026 (73.9)
#                                      True                                  363 (26.1)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,9.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    42.6 [13.7,134.5]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 307 (22.1)
#                                      True                                 1082 (77.9)
# VENT_FIRST_48_ICU, n (%)             False                                   66 (4.8)
#                                      True                                 1323 (95.2)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.2 [1.5,37.8]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.6,6.2]
#
#                                                                                        \
#                                                                                 False
# n                                                                                1187
# SEX, n (%)                           F                                     587 (49.5)
#                                      M                                     600 (50.5)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     111 (9.7)
#                                      MARRIED                               425 (37.1)
#                                      SINGLE                                427 (37.3)
#                                      WIDOWED                               182 (15.9)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   30 (2.5)
#                                      BLACK/AFRICAN AMERICAN                150 (12.6)
#                                      HISPANIC/LATINO                         47 (4.0)
# ...
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                                 0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                               582
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                               582
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                               582
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                                 0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                                 0
#                                      True
# SOFA, median [Q1,Q3]                                                                       0
# VENT_TOTAL_HOURS, median [Q1,Q3]                                                           0
# VENT_TOTAL_COUNT, median [Q1,Q3]                                                           0
# VENT_FIRST_48_HADM, n (%)            False                                                 0
#                                      True
# VENT_FIRST_48_ICU, n (%)             False                                                 0
#                                      True
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                                        0
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                                         0
#
#                                                                                        \
#                                                                               Overall
# n                                                                                1389
# SEX, n (%)                           F                                     666 (47.9)
#                                      M                                     723 (52.1)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                     119 (8.9)
#                                      MARRIED                               595 (44.3)
#                                      SINGLE                                438 (32.6)
#                                      WIDOWED                               190 (14.2)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   40 (2.9)
#                                      BLACK/AFRICAN AMERICAN                160 (11.5)
#                                      HISPANIC/LATINO                         53 (3.8)
#                                      OTHER                                   29 (2.1)
#                                      UNKNOWN/NOT SPECIFIED                   71 (5.1)
#                                      WHITE                                1035 (74.5)
# LANGUAGE, n (%)                      ENGL                                 1207 (86.9)
#                                      OTHER                                   73 (5.3)
#                                      PTUN                                    40 (2.9)
#                                      RUSS                                    34 (2.4)
#                                      SPAN                                    35 (2.5)
# ADMISSION_AGE, median [Q1,Q3]                                        64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                               9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          343 (24.7)
#                                      HOME                                  169 (12.2)
#                                      HOME HEALTH CARE                      222 (16.0)
#                                      HOSPICE                                 30 (2.2)
#                                      LONG TERM CARE HOSPITAL               249 (17.9)
#                                      OTHER                                   70 (5.0)
#                                      SNF                                   306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                1046 (75.3)
#                                      True                                  343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 323 (40.0)
#                                      True                                  484 (60.0)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                 166 (20.6)
#                                      True                                  641 (79.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 242 (30.0)
#                                      True                                  565 (70.0)
# IDENTIFIED_CONV_GOC, n (%)           False                                 443 (31.9)
#                                      True                                  946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                                1026 (73.9)
#                                      True                                  363 (26.1)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,9.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    42.6 [13.7,134.5]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 307 (22.1)
#                                      True                                 1082 (77.9)
# VENT_FIRST_48_ICU, n (%)             False                                   66 (4.8)
#                                      True                                 1323 (95.2)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.2 [1.5,37.8]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.6,6.2]
#
#                                                                                        \
#                                                                                 False
# n                                                                                 531
# SEX, n (%)                           F                                     245 (46.1)
#                                      M                                     286 (53.9)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                      43 (8.4)
#                                      MARRIED                               116 (22.8)
#                                      SINGLE                                298 (58.5)
#                                      WIDOWED                                52 (10.2)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE
#                                      ASIAN                                   10 (1.9)
#                                      BLACK/AFRICAN AMERICAN                 74 (13.9)
#                                      HISPANIC/LATINO                         25 (4.7)
#                                      OTHER                                    9 (1.7)
#                                      UNKNOWN/NOT SPECIFIED                   28 (5.3)
#                                      WHITE                                 385 (72.5)
# LANGUAGE, n (%)                      ENGL                                  484 (91.1)
#                                      OTHER                                   16 (3.0)
#                                      PTUN                                    10 (1.9)
#                                      RUSS                                     8 (1.5)
#                                      SPAN                                    13 (2.4)
# ADMISSION_AGE, median [Q1,Q3]                                        59.1 [47.5,72.4]
# LOS_HADM, median [Q1,Q3]                                               8.8 [4.8,17.9]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                           90 (16.9)
#                                      HOME                                   72 (13.6)
#                                      HOME HEALTH CARE                       96 (18.1)
#                                      HOSPICE                                 12 (2.3)
#                                      LONG TERM CARE HOSPITAL               102 (19.2)
#                                      OTHER                                   41 (7.7)
#                                      SNF                                   118 (22.2)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                 441 (83.1)
#                                      True                                   90 (16.9)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 122 (46.2)
#                                      True                                  142 (53.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                  65 (24.6)
#                                      True                                  199 (75.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                  96 (36.4)
#                                      True                                  168 (63.6)
# IDENTIFIED_CONV_GOC, n (%)           False                                 236 (44.4)
#                                      True                                  295 (55.6)
# IDENTIFIED_CONV_LIM, n (%)           False                                 442 (83.2)
#                                      True                                   89 (16.8)
# SOFA, median [Q1,Q3]                                                    5.0 [3.0,8.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    36.0 [12.0,134.2]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,1.0]
# VENT_FIRST_48_HADM, n (%)            False                                 112 (21.1)
#                                      True                                  419 (78.9)
# VENT_FIRST_48_ICU, n (%)             False                                   30 (5.6)
#                                      True                                  501 (94.4)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    4.7 [1.5,35.2]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      2.0 [0.8,6.7]
#
#
#                                                                                  True
# n                                                                                 858
# SEX, n (%)                           F                                     421 (49.1)
#                                      M                                     437 (50.9)
# MARITAL_STATUS, n (%)                DIVORCED/SEPARATED                      76 (9.1)
#                                      MARRIED                               479 (57.5)
#                                      SINGLE                                140 (16.8)
#                                      WIDOWED                               138 (16.6)
# ETHNICITY, n (%)                     AMERICAN INDIAN/ALASKA NATIVE            1 (0.1)
#                                      ASIAN                                   30 (3.5)
#                                      BLACK/AFRICAN AMERICAN                 86 (10.0)
#                                      HISPANIC/LATINO                         28 (3.3)
#                                      OTHER                                   20 (2.3)
#                                      UNKNOWN/NOT SPECIFIED                   43 (5.0)
#                                      WHITE                                 650 (75.8)
# LANGUAGE, n (%)                      ENGL                                  723 (84.3)
#                                      OTHER                                   57 (6.6)
#                                      PTUN                                    30 (3.5)
#                                      RUSS                                    26 (3.0)
#                                      SPAN                                    22 (2.6)
# ADMISSION_AGE, median [Q1,Q3]                                        68.4 [56.5,79.4]
# LOS_HADM, median [Q1,Q3]                                               9.0 [4.9,16.8]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                          253 (29.5)
#                                      HOME                                   97 (11.3)
#                                      HOME HEALTH CARE                      126 (14.7)
#                                      HOSPICE                                 18 (2.1)
#                                      LONG TERM CARE HOSPITAL               147 (17.1)
#                                      OTHER                                   29 (3.4)
#                                      SNF                                   188 (21.9)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                 605 (70.5)
#                                      True                                  253 (29.5)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                 201 (37.0)
#                                      True                                  342 (63.0)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                 101 (18.6)
#                                      True                                  442 (81.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                 146 (26.9)
#                                      True                                  397 (73.1)
# IDENTIFIED_CONV_GOC, n (%)           False                                 207 (24.1)
#                                      True                                  651 (75.9)
# IDENTIFIED_CONV_LIM, n (%)           False                                 584 (68.1)
#                                      True                                  274 (31.9)
# SOFA, median [Q1,Q3]                                                    6.0 [4.0,9.0]
# VENT_TOTAL_HOURS, median [Q1,Q3]                                    46.1 [16.0,134.9]
# VENT_TOTAL_COUNT, median [Q1,Q3]                                        1.0 [1.0,2.0]
# VENT_FIRST_48_HADM, n (%)            False                                 195 (22.7)
#                                      True                                  663 (77.3)
# VENT_FIRST_48_ICU, n (%)             False                                   36 (4.2)
#                                      True                                  822 (95.8)
# VENT_TIME_FROM_HADM, median [Q1,Q3]                                    3.9 [1.5,39.6]
# VENT_TIME_FROM_ICU, median [Q1,Q3]                                      1.9 [0.5,5.6]
