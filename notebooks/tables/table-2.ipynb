# %%
import pandas as pd
from tableone import TableOne

from cleaning.caregivers.main import load_data
from notebooks.tables.ref import columns, nonnormal

df = load_data()

table = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION",
    nonnormal = nonnormal,
    pval = True
)

# %% [markdown]
# # Table 2
# Study population stratified by child, spouse, and both (unadjusted)

# %%
table
# Out:
#                                                              Grouped by ANNOTATION
#                                                                            Missing           Overall              BOTH             CHILD           NEITHER            SPOUSE P-Value
# n                                                                                               1389               202               352               531               304
# SEX, n (%)                           F                                           0        666 (47.9)         79 (39.1)        235 (66.8)        245 (46.1)        107 (35.2)  <0.001
#                                      M                                                    723 (52.1)        123 (60.9)        117 (33.2)        286 (53.9)        197 (64.8)
# MARITAL_STATUS, n (%)                MARRIED                                    47        595 (44.3)        170 (86.3)         72 (21.4)        116 (22.8)        237 (79.3)  <0.001
#                                      NOT MARRIED                                          747 (55.7)         27 (13.7)        265 (78.6)        393 (77.2)         62 (20.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                        0       1035 (74.5)        163 (80.7)        242 (68.8)        385 (72.5)        245 (80.6)  <0.001
#                                      OTHER                                                283 (20.4)         29 (14.4)         95 (27.0)        118 (22.2)         41 (13.5)
#                                      UNKNOWN/NOT SPECIFIED                                  71 (5.1)          10 (5.0)          15 (4.3)          28 (5.3)          18 (5.9)
# ADMISSION_AGE, median [Q1,Q3]                                                    0  64.9 [53.3,76.9]  69.7 [61.0,77.4]  76.7 [66.0,85.0]  59.1 [47.5,72.4]  58.4 [48.4,67.0]  <0.001
# LOS_HADM, median [Q1,Q3]                                                         0    9.0 [4.9,17.2]    8.6 [4.7,16.1]    8.0 [4.7,14.7]    8.8 [4.8,17.9]   12.1 [6.0,21.1]  <0.001
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                0        343 (24.7)         81 (40.1)        109 (31.0)         90 (16.9)         63 (20.7)  <0.001
#                                      HOME                                                 169 (12.2)          11 (5.4)          29 (8.2)         72 (13.6)         57 (18.8)
#                                      HOME HEALTH CARE                                     222 (16.0)         25 (12.4)         55 (15.6)         96 (18.1)         46 (15.1)
#                                      HOSPICE                                                30 (2.2)           5 (2.5)           4 (1.1)          12 (2.3)           9 (3.0)
#                                      LONG TERM CARE HOSPITAL                              249 (17.9)         40 (19.8)         59 (16.8)        102 (19.2)         48 (15.8)
#                                      OTHER                                                  70 (5.0)           5 (2.5)           5 (1.4)          41 (7.7)          19 (6.2)
#                                      SNF                                                  306 (22.0)         35 (17.3)         91 (25.9)        118 (22.2)         62 (20.4)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                       0       1046 (75.3)        121 (59.9)        243 (69.0)        441 (83.1)        241 (79.3)  <0.001
#                                      True                                                 343 (24.7)         81 (40.1)        109 (31.0)         90 (16.9)         63 (20.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                       0        905 (65.2)        104 (51.5)        200 (56.8)        389 (73.3)        212 (69.7)  <0.001
#                                      True                                                 484 (34.8)         98 (48.5)        152 (43.2)        142 (26.7)         92 (30.3)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                       0        748 (53.9)         84 (41.6)        154 (43.8)        332 (62.5)        178 (58.6)  <0.001
#                                      True                                                 641 (46.1)        118 (58.4)        198 (56.2)        199 (37.5)        126 (41.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                       0        823 (59.3)         94 (46.5)        179 (50.9)        362 (68.2)        188 (61.8)  <0.001
#                                      True                                                 566 (40.7)        108 (53.5)        173 (49.1)        169 (31.8)        116 (38.2)
# HAS_READMISSION, n (%)               False                                       0       1030 (74.2)        159 (78.7)        262 (74.4)        368 (69.3)        241 (79.3)   0.005
#                                      True                                                 359 (25.8)         43 (21.3)         90 (25.6)        163 (30.7)         63 (20.7)
# IDENTIFIED_CONV_GOC, n (%)           False                                       0        443 (31.9)         38 (18.8)         86 (24.4)        236 (44.4)         83 (27.3)  <0.001
#                                      True                                                 946 (68.1)        164 (81.2)        266 (75.6)        295 (55.6)        221 (72.7)
# IDENTIFIED_CONV_LIM, n (%)           False                                       0       1026 (73.9)        129 (63.9)        203 (57.7)        442 (83.2)        252 (82.9)  <0.001
#                                      True                                                 363 (26.1)         73 (36.1)        149 (42.3)         89 (16.8)         52 (17.1)
# SOFA, median [Q1,Q3]                                                             0     6.0 [4.0,9.0]    7.0 [5.0,10.0]     6.0 [4.0,9.0]     5.0 [3.0,8.0]     5.5 [3.0,8.0]  <0.001
# ELIX_SCORE, median [Q1,Q3]                                                       0     4.0 [3.0,6.0]     5.0 [3.0,6.0]     5.0 [3.0,6.0]     4.0 [3.0,6.0]     4.0 [3.0,6.0]   0.002
# [1] Chi-squared tests for the following variables may be invalid due to the low number of observations: DISCHARGE_LOCATION.
