# %%
import pandas as pd
from tableone import TableOne

from cleaning.caregivers.main import load_data
from notebooks.tables.ref import columns, nonnormal

df = load_data()


annotation_child = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_CHILD",
    nonnormal = nonnormal
)

annotation_spouse = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_SPOUSE",
    nonnormal = nonnormal
)

annotation_both = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_BOTH",
    nonnormal = nonnormal
)

annotation_any = TableOne(
    df,
    columns = columns,
    groupby = "ANNOTATION_ANY",
    nonnormal = nonnormal
)


table = pd.concat([
    annotation_child.tableone,
    annotation_spouse.tableone,
    annotation_both.tableone,
    annotation_any.tableone
], axis=1)

# %% [markdown]
# # Table 2
# Study population stratified by child, spouse, and both (unadjusted)

# %%
table
# Out:
#                                                              Grouped by ANNOTATION_CHILD  \
#                                                                                  Missing
# n
# SEX, n (%)                           F                                                 0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                          47
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                              0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                          0
# LOS_HADM, median [Q1,Q3]                                                               0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                      0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                             0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                             0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                             0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                             0
#                                      True
# HAS_READMISSION, n (%)               False                                             0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                             0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                             0
#                                      True
# SOFA, median [Q1,Q3]                                                                   0
# ELIX_SCORE, median [Q1,Q3]                                                             0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1389
# SEX, n (%)                           F                              666 (47.9)
#                                      M                              723 (52.1)
# MARITAL_STATUS, n (%)                MARRIED                        595 (44.3)
#                                      NOT MARRIED                    747 (55.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE          1035 (74.5)
#                                      OTHER                          283 (20.4)
#                                      UNKNOWN/NOT SPECIFIED            71 (5.1)
# ADMISSION_AGE, median [Q1,Q3]                                 64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                        9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   343 (24.7)
#                                      HOME                           169 (12.2)
#                                      HOME HEALTH CARE               222 (16.0)
#                                      HOSPICE                          30 (2.2)
#                                      LONG TERM CARE HOSPITAL        249 (17.9)
#                                      OTHER                            70 (5.0)
#                                      SNF                            306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         1046 (75.3)
#                                      True                           343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          905 (65.2)
#                                      True                           484 (34.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (53.9)
#                                      True                           641 (46.1)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (59.3)
#                                      True                           566 (40.7)
# HAS_READMISSION, n (%)               False                         1030 (74.2)
#                                      True                           359 (25.8)
# IDENTIFIED_CONV_GOC, n (%)           False                          443 (31.9)
#                                      True                           946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                         1026 (73.9)
#                                      True                           363 (26.1)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          835
# SEX, n (%)                           F                              352 (42.2)
#                                      M                              483 (57.8)
# MARITAL_STATUS, n (%)                MARRIED                        353 (43.7)
#                                      NOT MARRIED                    455 (56.3)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           630 (75.4)
#                                      OTHER                          159 (19.0)
#                                      UNKNOWN/NOT SPECIFIED            46 (5.5)
# ADMISSION_AGE, median [Q1,Q3]                                 58.8 [47.9,69.5]
# LOS_HADM, median [Q1,Q3]                                        9.6 [5.0,18.9]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   153 (18.3)
#                                      HOME                           129 (15.4)
#                                      HOME HEALTH CARE               142 (17.0)
#                                      HOSPICE                          21 (2.5)
#                                      LONG TERM CARE HOSPITAL        150 (18.0)
#                                      OTHER                            60 (7.2)
#                                      SNF                            180 (21.6)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          682 (81.7)
#                                      True                           153 (18.3)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          601 (72.0)
#                                      True                           234 (28.0)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          510 (61.1)
#                                      True                           325 (38.9)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          550 (65.9)
#                                      True                           285 (34.1)
# HAS_READMISSION, n (%)               False                          609 (72.9)
#                                      True                           226 (27.1)
# IDENTIFIED_CONV_GOC, n (%)           False                          319 (38.2)
#                                      True                           516 (61.8)
# IDENTIFIED_CONV_LIM, n (%)           False                          694 (83.1)
#                                      True                           141 (16.9)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          554
# SEX, n (%)                           F                              314 (56.7)
#                                      M                              240 (43.3)
# MARITAL_STATUS, n (%)                MARRIED                        242 (45.3)
#                                      NOT MARRIED                    292 (54.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           405 (73.1)
#                                      OTHER                          124 (22.4)
#                                      UNKNOWN/NOT SPECIFIED            25 (4.5)
# ADMISSION_AGE, median [Q1,Q3]                                 74.5 [63.2,83.1]
# LOS_HADM, median [Q1,Q3]                                        8.1 [4.7,15.4]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   190 (34.3)
#                                      HOME                             40 (7.2)
#                                      HOME HEALTH CARE                80 (14.4)
#                                      HOSPICE                           9 (1.6)
#                                      LONG TERM CARE HOSPITAL         99 (17.9)
#                                      OTHER                            10 (1.8)
#                                      SNF                            126 (22.7)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          364 (65.7)
#                                      True                           190 (34.3)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          304 (54.9)
#                                      True                           250 (45.1)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          238 (43.0)
#                                      True                           316 (57.0)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          273 (49.3)
#                                      True                           281 (50.7)
# HAS_READMISSION, n (%)               False                          421 (76.0)
#                                      True                           133 (24.0)
# IDENTIFIED_CONV_GOC, n (%)           False                          124 (22.4)
#                                      True                           430 (77.6)
# IDENTIFIED_CONV_LIM, n (%)           False                          332 (59.9)
#                                      True                           222 (40.1)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       5.0 [3.0,6.0]
#
#                                                              Grouped by ANNOTATION_SPOUSE  \
#                                                                                   Missing
# n
# SEX, n (%)                           F                                                  0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                           47
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                               0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                           0
# LOS_HADM, median [Q1,Q3]                                                                0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                       0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                              0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                              0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                              0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                              0
#                                      True
# HAS_READMISSION, n (%)               False                                              0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                              0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                              0
#                                      True
# SOFA, median [Q1,Q3]                                                                    0
# ELIX_SCORE, median [Q1,Q3]                                                              0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1389
# SEX, n (%)                           F                              666 (47.9)
#                                      M                              723 (52.1)
# MARITAL_STATUS, n (%)                MARRIED                        595 (44.3)
#                                      NOT MARRIED                    747 (55.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE          1035 (74.5)
#                                      OTHER                          283 (20.4)
#                                      UNKNOWN/NOT SPECIFIED            71 (5.1)
# ADMISSION_AGE, median [Q1,Q3]                                 64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                        9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   343 (24.7)
#                                      HOME                           169 (12.2)
#                                      HOME HEALTH CARE               222 (16.0)
#                                      HOSPICE                          30 (2.2)
#                                      LONG TERM CARE HOSPITAL        249 (17.9)
#                                      OTHER                            70 (5.0)
#                                      SNF                            306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         1046 (75.3)
#                                      True                           343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          905 (65.2)
#                                      True                           484 (34.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (53.9)
#                                      True                           641 (46.1)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (59.3)
#                                      True                           566 (40.7)
# HAS_READMISSION, n (%)               False                         1030 (74.2)
#                                      True                           359 (25.8)
# IDENTIFIED_CONV_GOC, n (%)           False                          443 (31.9)
#                                      True                           946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                         1026 (73.9)
#                                      True                           363 (26.1)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          883
# SEX, n (%)                           F                              480 (54.4)
#                                      M                              403 (45.6)
# MARITAL_STATUS, n (%)                MARRIED                        188 (22.2)
#                                      NOT MARRIED                    658 (77.8)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           627 (71.0)
#                                      OTHER                          213 (24.1)
#                                      UNKNOWN/NOT SPECIFIED            43 (4.9)
# ADMISSION_AGE, median [Q1,Q3]                                 67.0 [53.4,79.5]
# LOS_HADM, median [Q1,Q3]                                        8.5 [4.8,16.5]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   199 (22.5)
#                                      HOME                           101 (11.4)
#                                      HOME HEALTH CARE               151 (17.1)
#                                      HOSPICE                          16 (1.8)
#                                      LONG TERM CARE HOSPITAL        161 (18.2)
#                                      OTHER                            46 (5.2)
#                                      SNF                            209 (23.7)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          684 (77.5)
#                                      True                           199 (22.5)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          589 (66.7)
#                                      True                           294 (33.3)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          486 (55.0)
#                                      True                           397 (45.0)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          541 (61.3)
#                                      True                           342 (38.7)
# HAS_READMISSION, n (%)               False                          630 (71.3)
#                                      True                           253 (28.7)
# IDENTIFIED_CONV_GOC, n (%)           False                          322 (36.5)
#                                      True                           561 (63.5)
# IDENTIFIED_CONV_LIM, n (%)           False                          645 (73.0)
#                                      True                           238 (27.0)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          506
# SEX, n (%)                           F                              186 (36.8)
#                                      M                              320 (63.2)
# MARITAL_STATUS, n (%)                MARRIED                        407 (82.1)
#                                      NOT MARRIED                     89 (17.9)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           408 (80.6)
#                                      OTHER                           70 (13.8)
#                                      UNKNOWN/NOT SPECIFIED            28 (5.5)
# ADMISSION_AGE, median [Q1,Q3]                                 62.9 [53.2,72.7]
# LOS_HADM, median [Q1,Q3]                                       10.6 [5.4,18.9]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   144 (28.5)
#                                      HOME                            68 (13.4)
#                                      HOME HEALTH CARE                71 (14.0)
#                                      HOSPICE                          14 (2.8)
#                                      LONG TERM CARE HOSPITAL         88 (17.4)
#                                      OTHER                            24 (4.7)
#                                      SNF                             97 (19.2)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          362 (71.5)
#                                      True                           144 (28.5)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          316 (62.5)
#                                      True                           190 (37.5)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          262 (51.8)
#                                      True                           244 (48.2)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          282 (55.7)
#                                      True                           224 (44.3)
# HAS_READMISSION, n (%)               False                          400 (79.1)
#                                      True                           106 (20.9)
# IDENTIFIED_CONV_GOC, n (%)           False                          121 (23.9)
#                                      True                           385 (76.1)
# IDENTIFIED_CONV_LIM, n (%)           False                          381 (75.3)
#                                      True                           125 (24.7)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.5 [3.0,6.0]
#
#                                                              Grouped by ANNOTATION_BOTH  \
#                                                                                 Missing
# n
# SEX, n (%)                           F                                                0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                         47
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                             0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                         0
# LOS_HADM, median [Q1,Q3]                                                              0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                     0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                            0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                            0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                            0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                            0
#                                      True
# HAS_READMISSION, n (%)               False                                            0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                            0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                            0
#                                      True
# SOFA, median [Q1,Q3]                                                                  0
# ELIX_SCORE, median [Q1,Q3]                                                            0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1389
# SEX, n (%)                           F                              666 (47.9)
#                                      M                              723 (52.1)
# MARITAL_STATUS, n (%)                MARRIED                        595 (44.3)
#                                      NOT MARRIED                    747 (55.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE          1035 (74.5)
#                                      OTHER                          283 (20.4)
#                                      UNKNOWN/NOT SPECIFIED            71 (5.1)
# ADMISSION_AGE, median [Q1,Q3]                                 64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                        9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   343 (24.7)
#                                      HOME                           169 (12.2)
#                                      HOME HEALTH CARE               222 (16.0)
#                                      HOSPICE                          30 (2.2)
#                                      LONG TERM CARE HOSPITAL        249 (17.9)
#                                      OTHER                            70 (5.0)
#                                      SNF                            306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         1046 (75.3)
#                                      True                           343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          905 (65.2)
#                                      True                           484 (34.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (53.9)
#                                      True                           641 (46.1)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (59.3)
#                                      True                           566 (40.7)
# HAS_READMISSION, n (%)               False                         1030 (74.2)
#                                      True                           359 (25.8)
# IDENTIFIED_CONV_GOC, n (%)           False                          443 (31.9)
#                                      True                           946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                         1026 (73.9)
#                                      True                           363 (26.1)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                         1187
# SEX, n (%)                           F                              587 (49.5)
#                                      M                              600 (50.5)
# MARITAL_STATUS, n (%)                MARRIED                        425 (37.1)
#                                      NOT MARRIED                    720 (62.9)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           872 (73.5)
#                                      OTHER                          254 (21.4)
#                                      UNKNOWN/NOT SPECIFIED            61 (5.1)
# ADMISSION_AGE, median [Q1,Q3]                                 63.5 [52.5,76.9]
# LOS_HADM, median [Q1,Q3]                                        9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   262 (22.1)
#                                      HOME                           158 (13.3)
#                                      HOME HEALTH CARE               197 (16.6)
#                                      HOSPICE                          25 (2.1)
#                                      LONG TERM CARE HOSPITAL        209 (17.6)
#                                      OTHER                            65 (5.5)
#                                      SNF                            271 (22.8)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          925 (77.9)
#                                      True                           262 (22.1)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          801 (67.5)
#                                      True                           386 (32.5)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          664 (55.9)
#                                      True                           523 (44.1)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          729 (61.4)
#                                      True                           458 (38.6)
# HAS_READMISSION, n (%)               False                          871 (73.4)
#                                      True                           316 (26.6)
# IDENTIFIED_CONV_GOC, n (%)           False                          405 (34.1)
#                                      True                           782 (65.9)
# IDENTIFIED_CONV_LIM, n (%)           False                          897 (75.6)
#                                      True                           290 (24.4)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                           True
# n                                                                          202
# SEX, n (%)                           F                               79 (39.1)
#                                      M                              123 (60.9)
# MARITAL_STATUS, n (%)                MARRIED                        170 (86.3)
#                                      NOT MARRIED                     27 (13.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           163 (80.7)
#                                      OTHER                           29 (14.4)
#                                      UNKNOWN/NOT SPECIFIED            10 (5.0)
# ADMISSION_AGE, median [Q1,Q3]                                 69.7 [61.0,77.4]
# LOS_HADM, median [Q1,Q3]                                        8.6 [4.7,16.1]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                    81 (40.1)
#                                      HOME                             11 (5.4)
#                                      HOME HEALTH CARE                25 (12.4)
#                                      HOSPICE                           5 (2.5)
#                                      LONG TERM CARE HOSPITAL         40 (19.8)
#                                      OTHER                             5 (2.5)
#                                      SNF                             35 (17.3)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          121 (59.9)
#                                      True                            81 (40.1)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          104 (51.5)
#                                      True                            98 (48.5)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                           84 (41.6)
#                                      True                           118 (58.4)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                           94 (46.5)
#                                      True                           108 (53.5)
# HAS_READMISSION, n (%)               False                          159 (78.7)
#                                      True                            43 (21.3)
# IDENTIFIED_CONV_GOC, n (%)           False                           38 (18.8)
#                                      True                           164 (81.2)
# IDENTIFIED_CONV_LIM, n (%)           False                          129 (63.9)
#                                      True                            73 (36.1)
# SOFA, median [Q1,Q3]                                            7.0 [5.0,10.0]
# ELIX_SCORE, median [Q1,Q3]                                       5.0 [3.0,6.0]
#
#                                                              Grouped by ANNOTATION_ANY  \
#                                                                                Missing
# n
# SEX, n (%)                           F                                               0
#                                      M
# MARITAL_STATUS, n (%)                MARRIED                                        47
#                                      NOT MARRIED
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE                            0
#                                      OTHER
#                                      UNKNOWN/NOT SPECIFIED
# ADMISSION_AGE, median [Q1,Q3]                                                        0
# LOS_HADM, median [Q1,Q3]                                                             0
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                                    0
#                                      HOME
#                                      HOME HEALTH CARE
#                                      HOSPICE
#                                      LONG TERM CARE HOSPITAL
#                                      OTHER
#                                      SNF
# HOSPITAL_EXPIRE_FLAG, n (%)          False                                           0
#                                      True
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                                           0
#                                      True
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                                           0
#                                      True
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                                           0
#                                      True
# HAS_READMISSION, n (%)               False                                           0
#                                      True
# IDENTIFIED_CONV_GOC, n (%)           False                                           0
#                                      True
# IDENTIFIED_CONV_LIM, n (%)           False                                           0
#                                      True
# SOFA, median [Q1,Q3]                                                                 0
# ELIX_SCORE, median [Q1,Q3]                                                           0
#
#                                                                                 \
#                                                                        Overall
# n                                                                         1389
# SEX, n (%)                           F                              666 (47.9)
#                                      M                              723 (52.1)
# MARITAL_STATUS, n (%)                MARRIED                        595 (44.3)
#                                      NOT MARRIED                    747 (55.7)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE          1035 (74.5)
#                                      OTHER                          283 (20.4)
#                                      UNKNOWN/NOT SPECIFIED            71 (5.1)
# ADMISSION_AGE, median [Q1,Q3]                                 64.9 [53.3,76.9]
# LOS_HADM, median [Q1,Q3]                                        9.0 [4.9,17.2]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   343 (24.7)
#                                      HOME                           169 (12.2)
#                                      HOME HEALTH CARE               222 (16.0)
#                                      HOSPICE                          30 (2.2)
#                                      LONG TERM CARE HOSPITAL        249 (17.9)
#                                      OTHER                            70 (5.0)
#                                      SNF                            306 (22.0)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                         1046 (75.3)
#                                      True                           343 (24.7)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          905 (65.2)
#                                      True                           484 (34.8)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          748 (53.9)
#                                      True                           641 (46.1)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          823 (59.3)
#                                      True                           566 (40.7)
# HAS_READMISSION, n (%)               False                         1030 (74.2)
#                                      True                           359 (25.8)
# IDENTIFIED_CONV_GOC, n (%)           False                          443 (31.9)
#                                      True                           946 (68.1)
# IDENTIFIED_CONV_LIM, n (%)           False                         1026 (73.9)
#                                      True                           363 (26.1)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#                                                                                 \
#                                                                          False
# n                                                                          531
# SEX, n (%)                           F                              245 (46.1)
#                                      M                              286 (53.9)
# MARITAL_STATUS, n (%)                MARRIED                        116 (22.8)
#                                      NOT MARRIED                    393 (77.2)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           385 (72.5)
#                                      OTHER                          118 (22.2)
#                                      UNKNOWN/NOT SPECIFIED            28 (5.3)
# ADMISSION_AGE, median [Q1,Q3]                                 59.1 [47.5,72.4]
# LOS_HADM, median [Q1,Q3]                                        8.8 [4.8,17.9]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                    90 (16.9)
#                                      HOME                            72 (13.6)
#                                      HOME HEALTH CARE                96 (18.1)
#                                      HOSPICE                          12 (2.3)
#                                      LONG TERM CARE HOSPITAL        102 (19.2)
#                                      OTHER                            41 (7.7)
#                                      SNF                            118 (22.2)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          441 (83.1)
#                                      True                            90 (16.9)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          389 (73.3)
#                                      True                           142 (26.7)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          332 (62.5)
#                                      True                           199 (37.5)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          362 (68.2)
#                                      True                           169 (31.8)
# HAS_READMISSION, n (%)               False                          368 (69.3)
#                                      True                           163 (30.7)
# IDENTIFIED_CONV_GOC, n (%)           False                          236 (44.4)
#                                      True                           295 (55.6)
# IDENTIFIED_CONV_LIM, n (%)           False                          442 (83.2)
#                                      True                            89 (16.8)
# SOFA, median [Q1,Q3]                                             5.0 [3.0,8.0]
# ELIX_SCORE, median [Q1,Q3]                                       4.0 [3.0,6.0]
#
#
#                                                                           True
# n                                                                          858
# SEX, n (%)                           F                              421 (49.1)
#                                      M                              437 (50.9)
# MARITAL_STATUS, n (%)                MARRIED                        479 (57.5)
#                                      NOT MARRIED                    354 (42.5)
# ETHNICITY, n (%)                     (NON-HISPANIC) WHITE           650 (75.8)
#                                      OTHER                          165 (19.2)
#                                      UNKNOWN/NOT SPECIFIED            43 (5.0)
# ADMISSION_AGE, median [Q1,Q3]                                 68.4 [56.5,79.4]
# LOS_HADM, median [Q1,Q3]                                        9.0 [4.9,16.8]
# DISCHARGE_LOCATION, n (%)            DEAD/EXPIRED                   253 (29.5)
#                                      HOME                            97 (11.3)
#                                      HOME HEALTH CARE               126 (14.7)
#                                      HOSPICE                          18 (2.1)
#                                      LONG TERM CARE HOSPITAL        147 (17.1)
#                                      OTHER                            29 (3.4)
#                                      SNF                            188 (21.9)
# HOSPITAL_EXPIRE_FLAG, n (%)          False                          605 (70.5)
#                                      True                           253 (29.5)
# MORTALITY_3MO_FROM_HADM_ADMIT, n (%) False                          516 (60.1)
#                                      True                           342 (39.9)
# MORTALITY_1Y_FROM_HADM_ADMIT, n (%)  False                          416 (48.5)
#                                      True                           442 (51.5)
# MORTALITY_6MO_FROM_ICU_OUT, n (%)    False                          461 (53.7)
#                                      True                           397 (46.3)
# HAS_READMISSION, n (%)               False                          662 (77.2)
#                                      True                           196 (22.8)
# IDENTIFIED_CONV_GOC, n (%)           False                          207 (24.1)
#                                      True                           651 (75.9)
# IDENTIFIED_CONV_LIM, n (%)           False                          584 (68.1)
#                                      True                           274 (31.9)
# SOFA, median [Q1,Q3]                                             6.0 [4.0,9.0]
# ELIX_SCORE, median [Q1,Q3]                                       5.0 [3.0,6.0]
