# %% [markdown]
# # Models: GOC Documentation, Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

from notebooks.models.ref import FORMULA_CONTROL

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "IDENTIFIED_CONV_GOC ~ {control_variables} + ANNOTATION_CHILD".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.602427
#          Iterations 5
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.8500         0.4896
# SEX[T.F]                                     1.0388         0.8198
# MARITAL_STATUS[T.NOT MARRIED]                0.9597         0.7531
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      0.9608         0.4700
# ETHNICITY[T.OTHER]                           0.7204         0.5412
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           0.9485         0.5274
# ADMISSION_AGE                                1.0060         0.9982
# ELIX_SCORE                                   0.9961         0.9424
# SOFA                                         1.0697         1.0352
# ANNOTATION_CHILD                             1.8793         1.4311
#
#                                          95% CI, upper  p-value
# Intercept                                       1.4757   0.5637
# SEX[T.F]                                        1.3164   0.7525
# MARITAL_STATUS[T.NOT MARRIED]                   1.2230   0.7395
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         1.9643   0.9128
# ETHNICITY[T.OTHER]                              0.9590   0.0246
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.7057   0.8598
# ADMISSION_AGE                                   1.0139   0.1340
# ELIX_SCORE                                      1.0528   0.8899
# SOFA                                            1.1054   0.0001
# ANNOTATION_CHILD                                2.4679   0.0000

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "IDENTIFIED_CONV_GOC ~ {control_variables} + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.597438
#          Iterations 5
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.2656         0.1443
# SEX[T.F]                                     1.1858         0.9357
# MARITAL_STATUS[T.NOT MARRIED]                1.5929         1.1849
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.5676         0.7526
# ETHNICITY[T.OTHER]                           0.8276         0.6208
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           0.8901         0.4950
# ADMISSION_AGE                                1.0178         1.0103
# ELIX_SCORE                                   0.9747         0.9214
# SOFA                                         1.0798         1.0450
# ANNOTATION_SPOUSE                            2.5086         1.8379
#
#                                          95% CI, upper  p-value
# Intercept                                       0.4887   0.0000
# SEX[T.F]                                        1.5027   0.1585
# MARITAL_STATUS[T.NOT MARRIED]                   2.1413   0.0020
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.2654   0.2299
# ETHNICITY[T.OTHER]                              1.1034   0.1973
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.6007   0.6974
# ADMISSION_AGE                                   1.0253   0.0000
# ELIX_SCORE                                      1.0310   0.3709
# SOFA                                            1.1157   0.0000
# ANNOTATION_SPOUSE                               3.4241   0.0000

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "IDENTIFIED_CONV_GOC ~ {control_variables} + ANNOTATION_CHILD + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.591196
#          Iterations 5
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.3720         0.1981
# SEX[T.F]                                     1.1042         0.8681
# MARITAL_STATUS[T.NOT MARRIED]                1.5476         1.1491
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.4819         0.7046
# ETHNICITY[T.OTHER]                           0.7766         0.5808
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           0.9098         0.5033
# ADMISSION_AGE                                1.0107         1.0026
# ELIX_SCORE                                   0.9797         0.9258
# SOFA                                         1.0711         1.0362
# ANNOTATION_CHILD                             1.7882         1.3568
# ANNOTATION_SPOUSE                            2.4008         1.7558
#
#                                          95% CI, upper  p-value
# Intercept                                       0.6985   0.0021
# SEX[T.F]                                        1.4044   0.4193
# MARITAL_STATUS[T.NOT MARRIED]                   2.0842   0.0040
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.1164   0.2998
# ETHNICITY[T.OTHER]                              1.0386   0.0883
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.6445   0.7543
# ADMISSION_AGE                                   1.0189   0.0096
# ELIX_SCORE                                      1.0366   0.4761
# SOFA                                            1.1071   0.0000
# ANNOTATION_CHILD                                2.3569   0.0000
# ANNOTATION_SPOUSE                               3.2828   0.0000

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "IDENTIFIED_CONV_GOC ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER'))".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.590429
#          Iterations 5
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.3686         0.1963
# SEX[T.F]                                     1.0908         0.8571
# MARITAL_STATUS[T.NOT MARRIED]                1.5339         1.1377
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.4805         0.7031
# ETHNICITY[T.OTHER]                           0.7703         0.5756
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           0.9030         0.4995
# ANNOTATION[T.BOTH]                           3.7071         2.3849
# ANNOTATION[T.CHILD]                          2.0410         1.4679
# ANNOTATION[T.SPOUSE]                         2.7113         1.9011
# ADMISSION_AGE                                1.0103         1.0021
# ELIX_SCORE                                   0.9801         0.9261
# SOFA                                         1.0719         1.0369
#
#                                          95% CI, upper  p-value
# Intercept                                       0.6923   0.0019
# SEX[T.F]                                        1.3883   0.4798
# MARITAL_STATUS[T.NOT MARRIED]                   2.0680   0.0050
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.1174   0.3018
# ETHNICITY[T.OTHER]                              1.0309   0.0792
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.6327   0.7357
# ANNOTATION[T.BOTH]                              5.7625   0.0000
# ANNOTATION[T.CHILD]                             2.8377   0.0000
# ANNOTATION[T.SPOUSE]                            3.8667   0.0000
# ADMISSION_AGE                                   1.0185   0.0132
# ELIX_SCORE                                      1.0371   0.4858
# SOFA                                            1.1081   0.0000
