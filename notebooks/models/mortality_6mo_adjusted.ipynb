# %% [markdown]
# # Models: Mortality (6-month, from ICU out), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

from notebooks.models.ref import FORMULA_CONTROL

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ {control_variables} + ANNOTATION_CHILD".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.589113
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0378         0.0202
# SEX[T.F]                                     0.6831         0.5363
# MARITAL_STATUS[T.NOT MARRIED]                0.7297         0.5720
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.2635         0.6283
# ETHNICITY[T.OTHER]                           0.9540         0.7074
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.0364         0.5732
# ADMISSION_AGE                                1.0252         1.0167
# ELIX_SCORE                                   1.0902         1.0314
# SOFA                                         1.1862         1.1476
# ANNOTATION_CHILD                             1.3477         1.0384
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0710   0.0000
# SEX[T.F]                                        0.8699   0.0020
# MARITAL_STATUS[T.NOT MARRIED]                   0.9308   0.0112
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.5409   0.5118
# ETHNICITY[T.OTHER]                              1.2867   0.7578
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.8740   0.9058
# ADMISSION_AGE                                   1.0338   0.0000
# ELIX_SCORE                                      1.1522   0.0023
# SOFA                                            1.2262   0.0000
# ANNOTATION_CHILD                                1.7492   0.0249

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ {control_variables} + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.590895
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0311         0.0158
# SEX[T.F]                                     0.7115         0.5598
# MARITAL_STATUS[T.NOT MARRIED]                0.7490         0.5564
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.3185         0.6482
# ETHNICITY[T.OTHER]                           0.9818         0.7279
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.0213         0.5655
# ADMISSION_AGE                                1.0292         1.0211
# ELIX_SCORE                                   1.0871         1.0284
# SOFA                                         1.1912         1.1527
# ANNOTATION_SPOUSE                            1.0429         0.7683
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0612   0.0000
# SEX[T.F]                                        0.9042   0.0054
# MARITAL_STATUS[T.NOT MARRIED]                   1.0083   0.0567
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.6818   0.4453
# ETHNICITY[T.OTHER]                              1.3242   0.9040
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.8444   0.9443
# ADMISSION_AGE                                   1.0373   0.0000
# ELIX_SCORE                                      1.1491   0.0032
# SOFA                                            1.2310   0.0000
# ANNOTATION_SPOUSE                               1.4155   0.7877

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ {control_variables} + ANNOTATION_CHILD + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.589112
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0375         0.0187
# SEX[T.F]                                     0.6836         0.5360
# MARITAL_STATUS[T.NOT MARRIED]                0.7333         0.5440
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.2686         0.6216
# ETHNICITY[T.OTHER]                           0.9547         0.7071
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.0364         0.5732
# ADMISSION_AGE                                1.0253         1.0166
# ELIX_SCORE                                   1.0900         1.0310
# SOFA                                         1.1862         1.1476
# ANNOTATION_CHILD                             1.3467         1.0364
# ANNOTATION_SPOUSE                            1.0088         0.7415
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0753   0.0000
# SEX[T.F]                                        0.8717   0.0022
# MARITAL_STATUS[T.NOT MARRIED]                   0.9885   0.0417
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.5891   0.5133
# ETHNICITY[T.OTHER]                              1.2891   0.7624
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.8737   0.9059
# ADMISSION_AGE                                   1.0340   0.0000
# ELIX_SCORE                                      1.1523   0.0024
# SOFA                                            1.2261   0.0000
# ANNOTATION_CHILD                                1.7500   0.0259
# ANNOTATION_SPOUSE                               1.3724   0.9556

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER'))".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.588846
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0370         0.0184
# SEX[T.F]                                     0.6782         0.5314
# MARITAL_STATUS[T.NOT MARRIED]                0.7290         0.5406
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.2672         0.6209
# ETHNICITY[T.OTHER]                           0.9521         0.7049
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.0352         0.5732
# ANNOTATION[T.BOTH]                           1.2956         0.8686
# ANNOTATION[T.CHILD]                          1.4655         1.0585
# ANNOTATION[T.SPOUSE]                         1.0982         0.7638
# ADMISSION_AGE                                1.0250         1.0163
# ELIX_SCORE                                   1.0902         1.0312
# SOFA                                         1.1869         1.1482
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0744   0.0000
# SEX[T.F]                                        0.8655   0.0018
# MARITAL_STATUS[T.NOT MARRIED]                   0.9830   0.0382
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.5862   0.5153
# ETHNICITY[T.OTHER]                              1.2859   0.7487
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.8698   0.9086
# ANNOTATION[T.BOTH]                              1.9324   0.2043
# ANNOTATION[T.CHILD]                             2.0289   0.0213
# ANNOTATION[T.SPOUSE]                            1.5790   0.6133
# ADMISSION_AGE                                   1.0338   0.0000
# ELIX_SCORE                                      1.1526   0.0023
# SOFA                                            1.2269   0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER')) + IDENTIFIED_CONV_GOC".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.576055
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0263         0.0128
# SEX[T.F]                                     0.6638         0.5183
# MARITAL_STATUS[T.NOT MARRIED]                0.6715         0.4943
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.2152         0.5937
# ETHNICITY[T.OTHER]                           0.9885         0.7286
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.0622         0.5834
# ANNOTATION[T.BOTH]                           1.0482         0.6941
# ANNOTATION[T.CHILD]                          1.3034         0.9350
# ANNOTATION[T.SPOUSE]                         0.9219         0.6340
# ADMISSION_AGE                                1.0238         1.0150
# ELIX_SCORE                                   1.0973         1.0369
# SOFA                                         1.1791         1.1403
# IDENTIFIED_CONV_GOC                          2.2593         1.7188
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0542   0.0000
# SEX[T.F]                                        0.8501   0.0012
# MARITAL_STATUS[T.NOT MARRIED]                   0.9121   0.0108
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.4872   0.5938
# ETHNICITY[T.OTHER]                              1.3411   0.9408
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              1.9339   0.8435
# ANNOTATION[T.BOTH]                              1.5828   0.8229
# ANNOTATION[T.CHILD]                             1.8168   0.1180
# ANNOTATION[T.SPOUSE]                            1.3404   0.6702
# ADMISSION_AGE                                   1.0327   0.0000
# ELIX_SCORE                                      1.1612   0.0013
# SOFA                                            1.2192   0.0000
# IDENTIFIED_CONV_GOC                             2.9698   0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "{control_variables} + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.575375
#          Iterations 6
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0254         0.0120
# SEX[T.F]                                      0.6630         0.5173
# MARITAL_STATUS[T.NOT MARRIED]                 0.6610         0.4857
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]       1.2356         0.6011
# ETHNICITY[T.OTHER]                            0.9986         0.7352
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]            1.0627         0.5817
# ANNOTATION[T.BOTH]                            1.2319         0.5510
# ANNOTATION[T.CHILD]                           1.1968         0.6533
# ANNOTATION[T.SPOUSE]                          1.2413         0.6663
# ADMISSION_AGE                                 1.0235         1.0147
# ELIX_SCORE                                    1.0972         1.0368
# SOFA                                          1.1798         1.1409
# IDENTIFIED_CONV_GOC                           2.4773         1.6312
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        0.7975         0.3273
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.1018         0.5498
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.6592         0.3207
#
#                                           95% CI, upper  p-value
# Intercept                                        0.0539   0.0000
# SEX[T.F]                                         0.8497   0.0012
# MARITAL_STATUS[T.NOT MARRIED]                    0.8995   0.0085
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]          2.5397   0.5650
# ETHNICITY[T.OTHER]                               1.3565   0.9931
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]               1.9415   0.8432
# ANNOTATION[T.BOTH]                               2.7542   0.6113
# ANNOTATION[T.CHILD]                              2.1923   0.5608
# ANNOTATION[T.SPOUSE]                             2.3125   0.4960
# ADMISSION_AGE                                    1.0324   0.0000
# ELIX_SCORE                                       1.1611   0.0013
# SOFA                                             1.2200   0.0000
# IDENTIFIED_CONV_GOC                              3.7624   0.0000
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC           1.9435   0.6186
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.2080   0.7847
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.3551   0.2570
