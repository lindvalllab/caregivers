# %% [markdown]
# # Models: Mortality (6-month, from ICU out), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.589113
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0496         0.0200         0.1225
# SEX[T.F]                               0.6831         0.5363         0.8699
# MARITAL_STATUS[T.MARRIED]              0.7915         0.3936         1.5917
# MARITAL_STATUS[T.NOT MARRIED]          0.5775         0.2876         1.1596
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.9649         0.5336         1.7446
# ETHNICITY[T.OTHER]                     0.9205         0.4885         1.7348
# ADMISSION_AGE                          1.0252         1.0167         1.0338
# ELIX_SCORE                             1.0902         1.0314         1.1522
# SOFA                                   1.1862         1.1476         1.2262
# ANNOTATION_CHILD                       1.3477         1.0384         1.7492
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0020
# MARITAL_STATUS[T.MARRIED]           0.5118
# MARITAL_STATUS[T.NOT MARRIED]       0.1227
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.9058
# ETHNICITY[T.OTHER]                  0.7978
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0023
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0249

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.590895
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0418         0.0169         0.1036
# SEX[T.F]                               0.7115         0.5598         0.9042
# MARITAL_STATUS[T.MARRIED]              0.7584         0.3729         1.5427
# MARITAL_STATUS[T.NOT MARRIED]          0.5681         0.2834         1.1386
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.9791         0.5422         1.7683
# ETHNICITY[T.OTHER]                     0.9613         0.5108         1.8092
# ADMISSION_AGE                          1.0292         1.0211         1.0373
# ELIX_SCORE                             1.0871         1.0284         1.1491
# SOFA                                   1.1912         1.1527         1.2310
# ANNOTATION_SPOUSE                      1.0429         0.7683         1.4155
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0054
# MARITAL_STATUS[T.MARRIED]           0.4453
# MARITAL_STATUS[T.NOT MARRIED]       0.1109
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.9443
# ETHNICITY[T.OTHER]                  0.9026
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0032
# SOFA                                0.0000
# ANNOTATION_SPOUSE                   0.7877

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.589112
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0493         0.0197         0.1237
# SEX[T.F]                               0.6836         0.5360         0.8717
# MARITAL_STATUS[T.MARRIED]              0.7883         0.3862         1.6087
# MARITAL_STATUS[T.NOT MARRIED]          0.5780         0.2877         1.1612
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.9649         0.5337         1.7445
# ETHNICITY[T.OTHER]                     0.9212         0.4886         1.7370
# ADMISSION_AGE                          1.0253         1.0166         1.0340
# ELIX_SCORE                             1.0900         1.0310         1.1523
# SOFA                                   1.1862         1.1476         1.2261
# ANNOTATION_CHILD                       1.3467         1.0364         1.7500
# ANNOTATION_SPOUSE                      1.0088         0.7415         1.3724
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0022
# MARITAL_STATUS[T.MARRIED]           0.5133
# MARITAL_STATUS[T.NOT MARRIED]       0.1236
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.9059
# ETHNICITY[T.OTHER]                  0.7999
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0024
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0259
# ANNOTATION_SPOUSE                   0.9556

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER'))"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.588846
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0486         0.0193         0.1219
# SEX[T.F]                               0.6782         0.5314         0.8655
# MARITAL_STATUS[T.MARRIED]              0.7891         0.3867         1.6105
# MARITAL_STATUS[T.NOT MARRIED]          0.5753         0.2863         1.1561
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.9660         0.5348         1.7447
# ETHNICITY[T.OTHER]                     0.9196         0.4881         1.7326
# ANNOTATION[T.BOTH]                     1.2956         0.8686         1.9324
# ANNOTATION[T.CHILD]                    1.4655         1.0585         2.0289
# ANNOTATION[T.SPOUSE]                   1.0982         0.7638         1.5790
# ADMISSION_AGE                          1.0250         1.0163         1.0338
# ELIX_SCORE                             1.0902         1.0312         1.1526
# SOFA                                   1.1869         1.1482         1.2269
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0018
# MARITAL_STATUS[T.MARRIED]           0.5153
# MARITAL_STATUS[T.NOT MARRIED]       0.1205
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.9086
# ETHNICITY[T.OTHER]                  0.7955
# ANNOTATION[T.BOTH]                  0.2043
# ANNOTATION[T.CHILD]                 0.0213
# ANNOTATION[T.SPOUSE]                0.6133
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0023
# SOFA                                0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.576055
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0340         0.0133         0.0870
# SEX[T.F]                               0.6638         0.5183         0.8501
# MARITAL_STATUS[T.MARRIED]              0.8229         0.4021         1.6843
# MARITAL_STATUS[T.NOT MARRIED]          0.5526         0.2744         1.1127
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.9414         0.5171         1.7140
# ETHNICITY[T.OTHER]                     0.9306         0.4896         1.7689
# ANNOTATION[T.BOTH]                     1.0482         0.6941         1.5828
# ANNOTATION[T.CHILD]                    1.3034         0.9350         1.8168
# ANNOTATION[T.SPOUSE]                   0.9219         0.6340         1.3404
# ADMISSION_AGE                          1.0238         1.0150         1.0327
# ELIX_SCORE                             1.0973         1.0369         1.1612
# SOFA                                   1.1791         1.1403         1.2192
# IDENTIFIED_CONV_GOC                    2.2593         1.7188         2.9698
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0012
# MARITAL_STATUS[T.MARRIED]           0.5938
# MARITAL_STATUS[T.NOT MARRIED]       0.0967
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.8435
# ETHNICITY[T.OTHER]                  0.8263
# ANNOTATION[T.BOTH]                  0.8229
# ANNOTATION[T.CHILD]                 0.1180
# ANNOTATION[T.SPOUSE]                0.6702
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0013
# SOFA                                0.0000
# IDENTIFIED_CONV_GOC                 0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "MORTALITY_6MO_FROM_ICU_OUT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.575375
#          Iterations 6
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0334         0.0126
# SEX[T.F]                                      0.6630         0.5173
# MARITAL_STATUS[T.MARRIED]                     0.8093         0.3938
# MARITAL_STATUS[T.NOT MARRIED]                 0.5349         0.2644
# ETHNICITY[T.(NON-HISPANIC) WHITE]             0.9410         0.5151
# ETHNICITY[T.OTHER]                            0.9397         0.4924
# ANNOTATION[T.BOTH]                            1.2319         0.5510
# ANNOTATION[T.CHILD]                           1.1968         0.6533
# ANNOTATION[T.SPOUSE]                          1.2413         0.6663
# ADMISSION_AGE                                 1.0235         1.0147
# ELIX_SCORE                                    1.0972         1.0368
# SOFA                                          1.1798         1.1409
# IDENTIFIED_CONV_GOC                           2.4773         1.6312
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        0.7975         0.3273
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.1018         0.5498
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.6592         0.3207
#
#                                           95% CI, upper  p-value
# Intercept                                        0.0880   0.0000
# SEX[T.F]                                         0.8497   0.0012
# MARITAL_STATUS[T.MARRIED]                        1.6636   0.5650
# MARITAL_STATUS[T.NOT MARRIED]                    1.0822   0.0818
# ETHNICITY[T.(NON-HISPANIC) WHITE]                1.7191   0.8432
# ETHNICITY[T.OTHER]                               1.7933   0.8504
# ANNOTATION[T.BOTH]                               2.7542   0.6113
# ANNOTATION[T.CHILD]                              2.1923   0.5608
# ANNOTATION[T.SPOUSE]                             2.3125   0.4960
# ADMISSION_AGE                                    1.0324   0.0000
# ELIX_SCORE                                       1.1611   0.0013
# SOFA                                             1.2200   0.0000
# IDENTIFIED_CONV_GOC                              3.7624   0.0000
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC           1.9435   0.6186
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.2080   0.7847
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.3551   0.2570
