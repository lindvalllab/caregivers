# %% [markdown]
# # Models: Mortality (in-hospital), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471377
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0716         0.0269         0.1901
# SEX[T.F]                               0.8193         0.6202         1.0822
# MARITAL_STATUS[T.MARRIED]              0.6655         0.3214         1.3782
# MARITAL_STATUS[T.NOT MARRIED]          0.4477         0.2159         0.9282
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.5626         0.3044         1.0401
# ETHNICITY[T.OTHER]                     0.5611         0.2876         1.0948
# ADMISSION_AGE                          1.0133         1.0036         1.0231
# ELIX_SCORE                             1.0153         0.9531         1.0817
# SOFA                                   1.2476         1.2024         1.2944
# ANNOTATION_CHILD                       1.8095         1.3431         2.4378
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.1605
# MARITAL_STATUS[T.MARRIED]           0.2729
# MARITAL_STATUS[T.NOT MARRIED]       0.0308
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.0666
# ETHNICITY[T.OTHER]                  0.0902
# ADMISSION_AGE                       0.0069
# ELIX_SCORE                          0.6376
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0001

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.476595
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0488         0.0184         0.1296
# SEX[T.F]                               0.8904         0.6760         1.1728
# MARITAL_STATUS[T.MARRIED]              0.5910         0.2811         1.2429
# MARITAL_STATUS[T.NOT MARRIED]          0.4365         0.2107         0.9043
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.5860         0.3174         1.0820
# ETHNICITY[T.OTHER]                     0.6126         0.3146         1.1931
# ADMISSION_AGE                          1.0217         1.0127         1.0309
# ELIX_SCORE                             1.0098         0.9481         1.0755
# SOFA                                   1.2563         1.2112         1.3031
# ANNOTATION_SPOUSE                      1.1719         0.8289         1.6567
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.4089
# MARITAL_STATUS[T.MARRIED]           0.1656
# MARITAL_STATUS[T.NOT MARRIED]       0.0257
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.0876
# ETHNICITY[T.OTHER]                  0.1496
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.7624
# SOFA                                0.0000
# ANNOTATION_SPOUSE                   0.3693

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471291
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0684         0.0253         0.1849
# SEX[T.F]                               0.8258         0.6240         1.0928
# MARITAL_STATUS[T.MARRIED]              0.6392         0.3032         1.3477
# MARITAL_STATUS[T.NOT MARRIED]          0.4517         0.2177         0.9373
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.5619         0.3042         1.0380
# ETHNICITY[T.OTHER]                     0.5642         0.2893         1.1003
# ADMISSION_AGE                          1.0138         1.0039         1.0238
# ELIX_SCORE                             1.0137         0.9513         1.0803
# SOFA                                   1.2475         1.2023         1.2943
# ANNOTATION_CHILD                       1.7953         1.3304         2.4227
# ANNOTATION_SPOUSE                      1.0910         0.7683         1.5493
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.1805
# MARITAL_STATUS[T.MARRIED]           0.2396
# MARITAL_STATUS[T.NOT MARRIED]       0.0329
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.0657
# ETHNICITY[T.OTHER]                  0.0930
# ADMISSION_AGE                       0.0061
# ELIX_SCORE                          0.6746
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0001
# ANNOTATION_SPOUSE                   0.6263

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER'))"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471290
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0685         0.0253         0.1855
# SEX[T.F]                               0.8264         0.6241         1.0943
# MARITAL_STATUS[T.MARRIED]              0.6392         0.3032         1.3478
# MARITAL_STATUS[T.NOT MARRIED]          0.4520         0.2178         0.9381
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.5619         0.3041         1.0381
# ETHNICITY[T.OTHER]                     0.5643         0.2893         1.1007
# ANNOTATION[T.BOTH]                     1.9635         1.2625         3.0539
# ANNOTATION[T.CHILD]                    1.7798         1.2175         2.6018
# ANNOTATION[T.SPOUSE]                   1.0808         0.7006         1.6673
# ADMISSION_AGE                          1.0139         1.0039         1.0239
# ELIX_SCORE                             1.0137         0.9512         1.0803
# SOFA                                   1.2474         1.2022         1.2943
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.1833
# MARITAL_STATUS[T.MARRIED]           0.2397
# MARITAL_STATUS[T.NOT MARRIED]       0.0330
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.0657
# ETHNICITY[T.OTHER]                  0.0932
# ANNOTATION[T.BOTH]                  0.0028
# ANNOTATION[T.CHILD]                 0.0029
# ANNOTATION[T.SPOUSE]                0.7255
# ADMISSION_AGE                       0.0062
# ELIX_SCORE                          0.6752
# SOFA                                0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453285
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0388         0.0137         0.1099
# SEX[T.F]                               0.8106         0.6083         1.0802
# MARITAL_STATUS[T.MARRIED]              0.6619         0.3092         1.4171
# MARITAL_STATUS[T.NOT MARRIED]          0.4156         0.1970         0.8769
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.5279         0.2804         0.9940
# ETHNICITY[T.OTHER]                     0.5567         0.2800         1.1069
# ANNOTATION[T.BOTH]                     1.4663         0.9263         2.3212
# ANNOTATION[T.CHILD]                    1.5077         1.0213         2.2257
# ANNOTATION[T.SPOUSE]                   0.8265         0.5259         1.2991
# ADMISSION_AGE                          1.0122         1.0021         1.0223
# ELIX_SCORE                             1.0176         0.9538         1.0858
# SOFA                                   1.2412         1.1953         1.2888
# IDENTIFIED_CONV_GOC                    3.4094         2.3654         4.9143
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.1518
# MARITAL_STATUS[T.MARRIED]           0.2880
# MARITAL_STATUS[T.NOT MARRIED]       0.0212
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.0478
# ETHNICITY[T.OTHER]                  0.0949
# ANNOTATION[T.BOTH]                  0.1024
# ANNOTATION[T.CHILD]                 0.0388
# ANNOTATION[T.SPOUSE]                0.4089
# ADMISSION_AGE                       0.0176
# ELIX_SCORE                          0.5970
# SOFA                                0.0000
# IDENTIFIED_CONV_GOC                 0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451000
#          Iterations 7
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0408         0.0137
# SEX[T.F]                                      0.8184         0.6132
# MARITAL_STATUS[T.MARRIED]                     0.6717         0.3118
# MARITAL_STATUS[T.NOT MARRIED]                 0.4124         0.1942
# ETHNICITY[T.(NON-HISPANIC) WHITE]             0.5192         0.2741
# ETHNICITY[T.OTHER]                            0.5435         0.2717
# ANNOTATION[T.BOTH]                            0.5912         0.1578
# ANNOTATION[T.CHILD]                           1.4171         0.6179
# ANNOTATION[T.SPOUSE]                          1.5070         0.6494
# ADMISSION_AGE                                 1.0113         1.0012
# ELIX_SCORE                                    1.0173         0.9533
# SOFA                                          1.2420         1.1960
# IDENTIFIED_CONV_GOC                           3.4706         1.9714
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        2.7069         0.6804
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.0876         0.4373
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.4773         0.1862
#
#                                           95% CI, upper  p-value
# Intercept                                        0.1220   0.0000
# SEX[T.F]                                         1.0923   0.1736
# MARITAL_STATUS[T.MARRIED]                        1.4470   0.3095
# MARITAL_STATUS[T.NOT MARRIED]                    0.8760   0.0212
# ETHNICITY[T.(NON-HISPANIC) WHITE]                0.9833   0.0443
# ETHNICITY[T.OTHER]                               1.0874   0.0849
# ANNOTATION[T.BOTH]                               2.2150   0.4354
# ANNOTATION[T.CHILD]                              3.2501   0.4105
# ANNOTATION[T.SPOUSE]                             3.4970   0.3396
# ADMISSION_AGE                                    1.0215   0.0279
# ELIX_SCORE                                       1.0856   0.6053
# SOFA                                             1.2898   0.0000
# IDENTIFIED_CONV_GOC                              6.1098   0.0000
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC          10.7703   0.1576
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.7046   0.8567
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.2240   0.1237
