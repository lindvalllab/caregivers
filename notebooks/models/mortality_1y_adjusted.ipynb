# %% [markdown]
# # Models: Mortality (1-year, from hospital admit), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "MORTALITY_1Y_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.605021
#          Iterations 5
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0689         0.0283         0.1679
# SEX[T.F]                               0.6901         0.5442         0.8751
# MARITAL_STATUS[T.MARRIED]              0.6139         0.3023         1.2465
# MARITAL_STATUS[T.NOT MARRIED]          0.4820         0.2379         0.9763
# ETHNICITY[T.(NON-HISPANIC) WHITE]      1.0679         0.5915         1.9279
# ETHNICITY[T.OTHER]                     0.9303         0.4954         1.7470
# ADMISSION_AGE                          1.0255         1.0171         1.0338
# ELIX_SCORE                             1.1351         1.0742         1.1994
# SOFA                                   1.1550         1.1183         1.1930
# ANNOTATION_CHILD                       1.4179         1.0957         1.8348
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0022
# MARITAL_STATUS[T.MARRIED]           0.1770
# MARITAL_STATUS[T.NOT MARRIED]       0.0427
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.8275
# ETHNICITY[T.OTHER]                  0.8223
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0000
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0079

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_1Y_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.607508
#          Iterations 5
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0593         0.0243         0.1445
# SEX[T.F]                               0.7186         0.5679         0.9091
# MARITAL_STATUS[T.MARRIED]              0.6168         0.3009         1.2644
# MARITAL_STATUS[T.NOT MARRIED]          0.4708         0.2333         0.9500
# ETHNICITY[T.(NON-HISPANIC) WHITE]      1.0834         0.6008         1.9537
# ETHNICITY[T.OTHER]                     0.9704         0.5174         1.8200
# ADMISSION_AGE                          1.0296         1.0217         1.0375
# ELIX_SCORE                             1.1328         1.0720         1.1970
# SOFA                                   1.1610         1.1243         1.1988
# ANNOTATION_SPOUSE                      0.9457         0.6997         1.2781
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0059
# MARITAL_STATUS[T.MARRIED]           0.1870
# MARITAL_STATUS[T.NOT MARRIED]       0.0355
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.7900
# ETHNICITY[T.OTHER]                  0.9254
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0000
# SOFA                                0.0000
# ANNOTATION_SPOUSE                   0.7162

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_1Y_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.604886
#          Iterations 5
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0723         0.0293         0.1782
# SEX[T.F]                               0.6849         0.5394         0.8697
# MARITAL_STATUS[T.MARRIED]              0.6424         0.3118         1.3235
# MARITAL_STATUS[T.NOT MARRIED]          0.4782         0.2360         0.9689
# ETHNICITY[T.(NON-HISPANIC) WHITE]      1.0665         0.5901         1.9275
# ETHNICITY[T.OTHER]                     0.9215         0.4899         1.7333
# ADMISSION_AGE                          1.0249         1.0165         1.0335
# ELIX_SCORE                             1.1369         1.0757         1.2016
# SOFA                                   1.1552         1.1184         1.1932
# ANNOTATION_CHILD                       1.4287         1.1027         1.8510
# ANNOTATION_SPOUSE                      0.9094         0.6712         1.2322
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0019
# MARITAL_STATUS[T.MARRIED]           0.2302
# MARITAL_STATUS[T.NOT MARRIED]       0.0406
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.8311
# ETHNICITY[T.OTHER]                  0.7998
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0000
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0069
# ANNOTATION_SPOUSE                   0.5400

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "MORTALITY_1Y_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER'))"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.604735
#          Iterations 5
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0716         0.0290         0.1767
# SEX[T.F]                               0.6810         0.5360         0.8653
# MARITAL_STATUS[T.MARRIED]              0.6430         0.3120         1.3248
# MARITAL_STATUS[T.NOT MARRIED]          0.4764         0.2350         0.9657
# ETHNICITY[T.(NON-HISPANIC) WHITE]      1.0671         0.5908         1.9272
# ETHNICITY[T.OTHER]                     0.9197         0.4892         1.7290
# ANNOTATION[T.BOTH]                     1.2498         0.8400         1.8594
# ANNOTATION[T.CHILD]                    1.5203         1.1035         2.0945
# ANNOTATION[T.SPOUSE]                   0.9666         0.6776         1.3788
# ADMISSION_AGE                          1.0247         1.0162         1.0333
# ELIX_SCORE                             1.1370         1.0758         1.2017
# SOFA                                   1.1556         1.1187         1.1936
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0017
# MARITAL_STATUS[T.MARRIED]           0.2311
# MARITAL_STATUS[T.NOT MARRIED]       0.0397
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.8296
# ETHNICITY[T.OTHER]                  0.7950
# ANNOTATION[T.BOTH]                  0.2713
# ANNOTATION[T.CHILD]                 0.0104
# ANNOTATION[T.SPOUSE]                0.8512
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0000
# SOFA                                0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "MORTALITY_1Y_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.593851
#          Iterations 5
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0523         0.0209         0.1311
# SEX[T.F]                               0.6679         0.5242         0.8510
# MARITAL_STATUS[T.MARRIED]              0.6748         0.3276         1.3901
# MARITAL_STATUS[T.NOT MARRIED]          0.4647         0.2296         0.9403
# ETHNICITY[T.(NON-HISPANIC) WHITE]      1.0401         0.5725         1.8894
# ETHNICITY[T.OTHER]                     0.9278         0.4902         1.7562
# ANNOTATION[T.BOTH]                     1.0343         0.6876         1.5558
# ANNOTATION[T.CHILD]                    1.3712         0.9894         1.9002
# ANNOTATION[T.SPOUSE]                   0.8255         0.5731         1.1891
# ADMISSION_AGE                          1.0236         1.0150         1.0322
# ELIX_SCORE                             1.1449         1.0823         1.2111
# SOFA                                   1.1477         1.1109         1.1858
# IDENTIFIED_CONV_GOC                    2.0669         1.5907         2.6857
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0011
# MARITAL_STATUS[T.MARRIED]           0.2861
# MARITAL_STATUS[T.NOT MARRIED]       0.0331
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.8974
# ETHNICITY[T.OTHER]                  0.8179
# ANNOTATION[T.BOTH]                  0.8714
# ANNOTATION[T.CHILD]                 0.0580
# ANNOTATION[T.SPOUSE]                0.3031
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.0000
# SOFA                                0.0000
# IDENTIFIED_CONV_GOC                 0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "MORTALITY_1Y_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.593427
#          Iterations 6
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0533         0.0208
# SEX[T.F]                                      0.6674         0.5235
# MARITAL_STATUS[T.MARRIED]                     0.6664         0.3226
# MARITAL_STATUS[T.NOT MARRIED]                 0.4536         0.2234
# ETHNICITY[T.(NON-HISPANIC) WHITE]             1.0370         0.5694
# ETHNICITY[T.OTHER]                            0.9320         0.4909
# ANNOTATION[T.BOTH]                            1.0925         0.5026
# ANNOTATION[T.CHILD]                           1.2255         0.6953
# ANNOTATION[T.SPOUSE]                          1.0062         0.5553
# ADMISSION_AGE                                 1.0233         1.0147
# ELIX_SCORE                                    1.1447         1.0821
# SOFA                                          1.1481         1.1112
# IDENTIFIED_CONV_GOC                           2.1342         1.4395
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        0.9220         0.3882
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.1589         0.5979
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.7573         0.3785
#
#                                           95% CI, upper  p-value
# Intercept                                        0.1366   0.0000
# SEX[T.F]                                         0.8510   0.0011
# MARITAL_STATUS[T.MARRIED]                        1.3765   0.2728
# MARITAL_STATUS[T.NOT MARRIED]                    0.9208   0.0286
# ETHNICITY[T.(NON-HISPANIC) WHITE]                1.8887   0.9054
# ETHNICITY[T.OTHER]                               1.7695   0.8296
# ANNOTATION[T.BOTH]                               2.3749   0.8233
# ANNOTATION[T.CHILD]                              2.1599   0.4820
# ANNOTATION[T.SPOUSE]                             1.8233   0.9836
# ADMISSION_AGE                                    1.0320   0.0000
# ELIX_SCORE                                       1.2109   0.0000
# SOFA                                             1.1862   0.0000
# IDENTIFIED_CONV_GOC                              3.1641   0.0002
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC           2.1897   0.8540
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.2463   0.6624
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.5151   0.4320
