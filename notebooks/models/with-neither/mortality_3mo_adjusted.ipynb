# %% [markdown]
# # Models: Mortality (3-month, from hospital admit), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

from notebooks.models.ref import FORMULA_CONTROL

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ {control_variables} + ANNOTATION_CHILD".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.563899
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0336         0.0175
# SEX[T.F]                                     0.7302         0.5693
# MARITAL_STATUS[T.NOT MARRIED]                0.6874         0.5352
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.3742         0.6824
# ETHNICITY[T.OTHER]                           0.9297         0.6815
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.1606         0.6419
# ADMISSION_AGE                                1.0258         1.0169
# ELIX_SCORE                                   1.0263         0.9698
# SOFA                                         1.1928         1.1536
# ANNOTATION_CHILD                             1.4396         1.1035
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0646   0.0000
# SEX[T.F]                                        0.9365   0.0133
# MARITAL_STATUS[T.NOT MARRIED]                   0.8829   0.0033
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.7673   0.3735
# ETHNICITY[T.OTHER]                              1.2682   0.6453
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              2.0987   0.6221
# ADMISSION_AGE                                   1.0347   0.0000
# ELIX_SCORE                                      1.0861   0.3693
# SOFA                                            1.2335   0.0000
# ANNOTATION_CHILD                                1.8782   0.0072

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ {control_variables} + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.566449
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0292         0.0145
# SEX[T.F]                                     0.7616         0.5951
# MARITAL_STATUS[T.NOT MARRIED]                0.6686         0.4927
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.3799         0.6772
# ETHNICITY[T.OTHER]                           0.9525         0.6984
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.1352         0.6279
# ADMISSION_AGE                                1.0301         1.0218
# ELIX_SCORE                                   1.0251         0.9685
# SOFA                                         1.1991         1.1599
# ANNOTATION_SPOUSE                            0.9467         0.6918
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0588   0.0000
# SEX[T.F]                                        0.9746   0.0305
# MARITAL_STATUS[T.NOT MARRIED]                   0.9075   0.0098
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.8119   0.3752
# ETHNICITY[T.OTHER]                              1.2990   0.7583
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              2.0525   0.6747
# ADMISSION_AGE                                   1.0385   0.0000
# ELIX_SCORE                                      1.0849   0.3923
# SOFA                                            1.2397   0.0000
# ANNOTATION_SPOUSE                               1.2954   0.7321

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ {control_variables} + ANNOTATION_CHILD + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.563763
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0370         0.0180
# SEX[T.F]                                     0.7240         0.5636
# MARITAL_STATUS[T.NOT MARRIED]                0.6501         0.4782
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.3128         0.6421
# ETHNICITY[T.OTHER]                           0.9222         0.6754
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.1602         0.6409
# ADMISSION_AGE                                1.0252         1.0162
# ELIX_SCORE                                   1.0282         0.9712
# SOFA                                         1.1930         1.1537
# ANNOTATION_CHILD                             1.4519         1.1113
# ANNOTATION_SPOUSE                            0.9056         0.6599
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0760   0.0000
# SEX[T.F]                                        0.9300   0.0115
# MARITAL_STATUS[T.NOT MARRIED]                   0.8839   0.0060
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.6841   0.4558
# ETHNICITY[T.OTHER]                              1.2592   0.6104
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              2.1002   0.6236
# ADMISSION_AGE                                   1.0343   0.0000
# ELIX_SCORE                                      1.0884   0.3392
# SOFA                                            1.2337   0.0000
# ANNOTATION_CHILD                                1.8970   0.0063
# ANNOTATION_SPOUSE                               1.2429   0.5394

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER'))".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.563747
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0369         0.0179
# SEX[T.F]                                     0.7226         0.5622
# MARITAL_STATUS[T.NOT MARRIED]                0.6492         0.4773
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.3128         0.6421
# ETHNICITY[T.OTHER]                           0.9215         0.6748
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.1600         0.6410
# ANNOTATION[T.BOTH]                           1.3014         0.8684
# ANNOTATION[T.CHILD]                          1.4835         1.0628
# ANNOTATION[T.SPOUSE]                         0.9263         0.6341
# ADMISSION_AGE                                1.0251         1.0161
# ELIX_SCORE                                   1.0282         0.9713
# SOFA                                         1.1932         1.1538
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0758   0.0000
# SEX[T.F]                                        0.9289   0.0112
# MARITAL_STATUS[T.NOT MARRIED]                   0.8829   0.0059
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.6841   0.4558
# ETHNICITY[T.OTHER]                              1.2584   0.6071
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              2.0991   0.6239
# ANNOTATION[T.BOTH]                              1.9502   0.2019
# ANNOTATION[T.CHILD]                             2.0709   0.0205
# ANNOTATION[T.SPOUSE]                            1.3530   0.6920
# ADMISSION_AGE                                   1.0342   0.0000
# ELIX_SCORE                                      1.0885   0.3383
# SOFA                                            1.2339   0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER')) + IDENTIFIED_CONV_GOC".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.549731
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0253         0.0120
# SEX[T.F]                                     0.7080         0.5486
# MARITAL_STATUS[T.NOT MARRIED]                0.5880         0.4284
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.2574         0.6122
# ETHNICITY[T.OTHER]                           0.9590         0.6990
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.1967         0.6544
# ANNOTATION[T.BOTH]                           1.0279         0.6763
# ANNOTATION[T.CHILD]                          1.3040         0.9270
# ANNOTATION[T.SPOUSE]                         0.7548         0.5097
# ADMISSION_AGE                                1.0238         1.0147
# ELIX_SCORE                                   1.0327         0.9746
# SOFA                                         1.1855         1.1460
# IDENTIFIED_CONV_GOC                          2.4579         1.8364
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0535   0.0000
# SEX[T.F]                                        0.9137   0.0080
# MARITAL_STATUS[T.NOT MARRIED]                   0.8071   0.0010
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         2.5825   0.5328
# ETHNICITY[T.OTHER]                              1.3157   0.7952
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              2.1884   0.5599
# ANNOTATION[T.BOTH]                              1.5624   0.8974
# ANNOTATION[T.CHILD]                             1.8343   0.1273
# ANNOTATION[T.SPOUSE]                            1.1177   0.1602
# ADMISSION_AGE                                   1.0330   0.0000
# ELIX_SCORE                                      1.0942   0.2759
# SOFA                                            1.2263   0.0000
# IDENTIFIED_CONV_GOC                             3.2897   0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "{control_variables} + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.549193
#          Iterations 6
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0244         0.0112
# SEX[T.F]                                      0.7064         0.5469
# MARITAL_STATUS[T.NOT MARRIED]                 0.5804         0.4220
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]       1.2819         0.6212
# ETHNICITY[T.OTHER]                            0.9679         0.7047
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]            1.1943         0.6514
# ANNOTATION[T.BOTH]                            1.2259         0.5300
# ANNOTATION[T.CHILD]                           1.1940         0.6231
# ANNOTATION[T.SPOUSE]                          1.0093         0.5089
# ADMISSION_AGE                                 1.0236         1.0145
# ELIX_SCORE                                    1.0326         0.9745
# SOFA                                          1.1862         1.1466
# IDENTIFIED_CONV_GOC                           2.6719         1.7104
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        0.7903         0.3142
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.1041         0.5288
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.6773         0.3105
#
#                                           95% CI, upper  p-value
# Intercept                                        0.0533   0.0000
# SEX[T.F]                                         0.9123   0.0077
# MARITAL_STATUS[T.NOT MARRIED]                    0.7982   0.0008
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]          2.6453   0.5017
# ETHNICITY[T.OTHER]                               1.3293   0.8401
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]               2.1896   0.5660
# ANNOTATION[T.BOTH]                               2.8359   0.6340
# ANNOTATION[T.CHILD]                              2.2880   0.5931
# ANNOTATION[T.SPOUSE]                             2.0020   0.9788
# ADMISSION_AGE                                    1.0328   0.0000
# ELIX_SCORE                                       1.0941   0.2773
# SOFA                                             1.2271   0.0000
# IDENTIFIED_CONV_GOC                              4.1738   0.0000
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC           1.9881   0.6171
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.3054   0.7921
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.4774   0.3275
