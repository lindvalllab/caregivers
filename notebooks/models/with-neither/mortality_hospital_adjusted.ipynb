# %% [markdown]
# # Models: Mortality (in-hospital), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

from notebooks.models.ref import FORMULA_CONTROL

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ {control_variables} + ANNOTATION_CHILD".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471377
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0268         0.0129
# SEX[T.F]                                     0.8193         0.6202
# MARITAL_STATUS[T.NOT MARRIED]                0.6727         0.5075
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.5027         0.7256
# ETHNICITY[T.OTHER]                           0.9974         0.7046
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.7774         0.9615
# ADMISSION_AGE                                1.0133         1.0036
# ELIX_SCORE                                   1.0153         0.9531
# SOFA                                         1.2476         1.2024
# ANNOTATION_CHILD                             1.8095         1.3431
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0558   0.0000
# SEX[T.F]                                        1.0822   0.1605
# MARITAL_STATUS[T.NOT MARRIED]                   0.8917   0.0058
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.1119   0.2729
# ETHNICITY[T.OTHER]                              1.4118   0.9881
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              3.2856   0.0666
# ADMISSION_AGE                                   1.0231   0.0069
# ELIX_SCORE                                      1.0817   0.6376
# SOFA                                            1.2944   0.0000
# ANNOTATION_CHILD                                2.4378   0.0001

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ {control_variables} + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.476595
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0169         0.0076
# SEX[T.F]                                     0.8904         0.6760
# MARITAL_STATUS[T.NOT MARRIED]                0.7385         0.5245
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.6919         0.8046
# ETHNICITY[T.OTHER]                           1.0454         0.7389
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.7064         0.9242
# ADMISSION_AGE                                1.0217         1.0127
# ELIX_SCORE                                   1.0098         0.9481
# SOFA                                         1.2563         1.2112
# ANNOTATION_SPOUSE                            1.1719         0.8289
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0374   0.0000
# SEX[T.F]                                        1.1728   0.4089
# MARITAL_STATUS[T.NOT MARRIED]                   1.0398   0.0825
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.5579   0.1656
# ETHNICITY[T.OTHER]                              1.4790   0.8020
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              3.1507   0.0876
# ADMISSION_AGE                                   1.0309   0.0000
# ELIX_SCORE                                      1.0755   0.7624
# SOFA                                            1.3031   0.0000
# ANNOTATION_SPOUSE                               1.6567   0.3693

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ {control_variables} + ANNOTATION_CHILD + ANNOTATION_SPOUSE".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471291
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0246         0.0109
# SEX[T.F]                                     0.8258         0.6240
# MARITAL_STATUS[T.NOT MARRIED]                0.7067         0.5005
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.5645         0.7420
# ETHNICITY[T.OTHER]                           1.0040         0.7084
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.7796         0.9634
# ADMISSION_AGE                                1.0138         1.0039
# ELIX_SCORE                                   1.0137         0.9513
# SOFA                                         1.2475         1.2023
# ANNOTATION_CHILD                             1.7953         1.3304
# ANNOTATION_SPOUSE                            1.0910         0.7683
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0555   0.0000
# SEX[T.F]                                        1.0928   0.1805
# MARITAL_STATUS[T.NOT MARRIED]                   0.9980   0.0487
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.2986   0.2396
# ETHNICITY[T.OTHER]                              1.4228   0.9822
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              3.2874   0.0657
# ADMISSION_AGE                                   1.0238   0.0061
# ELIX_SCORE                                      1.0803   0.6746
# SOFA                                            1.2943   0.0000
# ANNOTATION_CHILD                                2.4227   0.0001
# ANNOTATION_SPOUSE                               1.5493   0.6263

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER'))".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471290
#          Iterations 6
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0246         0.0109
# SEX[T.F]                                     0.8264         0.6241
# MARITAL_STATUS[T.NOT MARRIED]                0.7071         0.5006
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.5644         0.7420
# ETHNICITY[T.OTHER]                           1.0043         0.7086
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.7797         0.9633
# ANNOTATION[T.BOTH]                           1.9635         1.2625
# ANNOTATION[T.CHILD]                          1.7798         1.2175
# ANNOTATION[T.SPOUSE]                         1.0808         0.7006
# ADMISSION_AGE                                1.0139         1.0039
# ELIX_SCORE                                   1.0137         0.9512
# SOFA                                         1.2474         1.2022
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0557   0.0000
# SEX[T.F]                                        1.0943   0.1833
# MARITAL_STATUS[T.NOT MARRIED]                   0.9988   0.0492
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.2985   0.2397
# ETHNICITY[T.OTHER]                              1.4233   0.9809
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              3.2881   0.0657
# ANNOTATION[T.BOTH]                              3.0539   0.0028
# ANNOTATION[T.CHILD]                             2.6018   0.0029
# ANNOTATION[T.SPOUSE]                            1.6673   0.7255
# ADMISSION_AGE                                   1.0239   0.0062
# ELIX_SCORE                                      1.0803   0.6752
# SOFA                                            1.2943   0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ {control_variables} + C(ANNOTATION, Treatment(reference='NEITHER')) + IDENTIFIED_CONV_GOC".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453285
#          Iterations 7
#                                          odds ratio  95% CI, lower  \
# Intercept                                    0.0136         0.0057
# SEX[T.F]                                     0.8106         0.6083
# MARITAL_STATUS[T.NOT MARRIED]                0.6280         0.4391
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]      1.5108         0.7057
# ETHNICITY[T.OTHER]                           1.0546         0.7390
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]           1.8943         1.0061
# ANNOTATION[T.BOTH]                           1.4663         0.9263
# ANNOTATION[T.CHILD]                          1.5077         1.0213
# ANNOTATION[T.SPOUSE]                         0.8265         0.5259
# ADMISSION_AGE                                1.0122         1.0021
# ELIX_SCORE                                   1.0176         0.9538
# SOFA                                         1.2412         1.1953
# IDENTIFIED_CONV_GOC                          3.4094         2.3654
#
#                                          95% CI, upper  p-value
# Intercept                                       0.0323   0.0000
# SEX[T.F]                                        1.0802   0.1518
# MARITAL_STATUS[T.NOT MARRIED]                   0.8981   0.0108
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]         3.2346   0.2880
# ETHNICITY[T.OTHER]                              1.5051   0.7696
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]              3.5665   0.0478
# ANNOTATION[T.BOTH]                              2.3212   0.1024
# ANNOTATION[T.CHILD]                             2.2257   0.0388
# ANNOTATION[T.SPOUSE]                            1.2991   0.4089
# ADMISSION_AGE                                   1.0223   0.0176
# ELIX_SCORE                                      1.0858   0.5970
# SOFA                                            1.2888   0.0000
# IDENTIFIED_CONV_GOC                             4.9143   0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "HOSPITAL_EXPIRE_FLAG ~ "\
    "{control_variables} + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC".format(control_variables=FORMULA_CONTROL)

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451000
#          Iterations 7
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0142         0.0057
# SEX[T.F]                                      0.8184         0.6132
# MARITAL_STATUS[T.NOT MARRIED]                 0.6140         0.4290
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]       1.4888         0.6911
# ETHNICITY[T.OTHER]                            1.0470         0.7326
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]            1.9262         1.0170
# ANNOTATION[T.BOTH]                            0.5912         0.1578
# ANNOTATION[T.CHILD]                           1.4171         0.6179
# ANNOTATION[T.SPOUSE]                          1.5070         0.6494
# ADMISSION_AGE                                 1.0113         1.0012
# ELIX_SCORE                                    1.0173         0.9533
# SOFA                                          1.2420         1.1960
# IDENTIFIED_CONV_GOC                           3.4706         1.9714
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        2.7069         0.6804
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.0876         0.4373
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.4773         0.1862
#
#                                           95% CI, upper  p-value
# Intercept                                        0.0358   0.0000
# SEX[T.F]                                         1.0923   0.1736
# MARITAL_STATUS[T.NOT MARRIED]                    0.8787   0.0076
# MARITAL_STATUS[T.UNKNOWN/NOT SPECIFIED]          3.2074   0.3095
# ETHNICITY[T.OTHER]                               1.4962   0.8010
# ETHNICITY[T.UNKNOWN/NOT SPECIFIED]               3.6484   0.0443
# ANNOTATION[T.BOTH]                               2.2150   0.4354
# ANNOTATION[T.CHILD]                              3.2501   0.4105
# ANNOTATION[T.SPOUSE]                             3.4970   0.3396
# ADMISSION_AGE                                    1.0215   0.0279
# ELIX_SCORE                                       1.0856   0.6053
# SOFA                                             1.2898   0.0000
# IDENTIFIED_CONV_GOC                              6.1098   0.0000
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC          10.7703   0.1576
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.7046   0.8567
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.2240   0.1237
