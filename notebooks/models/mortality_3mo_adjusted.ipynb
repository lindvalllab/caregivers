# %% [markdown]
# # Models: Mortality (3-month, from hospital admit), Adjusted

# %%
from cleaning.caregivers.models import (
    load_data,
    run_logit,
    format_logit_results
)

df = load_data()

# %% [markdown]
# ## Caregiver:Child[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.563899
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0536         0.0214         0.1344
# SEX[T.F]                               0.7302         0.5693         0.9365
# MARITAL_STATUS[T.MARRIED]              0.7277         0.3614         1.4654
# MARITAL_STATUS[T.NOT MARRIED]          0.5002         0.2485         1.0068
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.8616         0.4765         1.5580
# ETHNICITY[T.OTHER]                     0.8010         0.4234         1.5153
# ADMISSION_AGE                          1.0258         1.0169         1.0347
# ELIX_SCORE                             1.0263         0.9698         1.0861
# SOFA                                   1.1928         1.1536         1.2335
# ANNOTATION_CHILD                       1.4396         1.1035         1.8782
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0133
# MARITAL_STATUS[T.MARRIED]           0.3735
# MARITAL_STATUS[T.NOT MARRIED]       0.0523
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.6221
# ETHNICITY[T.OTHER]                  0.4951
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.3693
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0072

# %% [markdown]
# ## Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.566449
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0457         0.0182         0.1145
# SEX[T.F]                               0.7616         0.5951         0.9746
# MARITAL_STATUS[T.MARRIED]              0.7247         0.3556         1.4767
# MARITAL_STATUS[T.NOT MARRIED]          0.4845         0.2410         0.9740
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.8809         0.4872         1.5927
# ETHNICITY[T.OTHER]                     0.8390         0.4438         1.5863
# ADMISSION_AGE                          1.0301         1.0218         1.0385
# ELIX_SCORE                             1.0251         0.9685         1.0849
# SOFA                                   1.1991         1.1599         1.2397
# ANNOTATION_SPOUSE                      0.9467         0.6918         1.2954
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0305
# MARITAL_STATUS[T.MARRIED]           0.3752
# MARITAL_STATUS[T.NOT MARRIED]       0.0420
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.6747
# ETHNICITY[T.OTHER]                  0.5891
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.3923
# SOFA                                0.0000
# ANNOTATION_SPOUSE                   0.7321

# %% [markdown]
# ## Caregiver:Child[Binary] + Caregiver:Spouse[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "ANNOTATION_CHILD + "\
    "ANNOTATION_SPOUSE"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.563763
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0564         0.0222         0.1431
# SEX[T.F]                               0.7240         0.5636         0.9300
# MARITAL_STATUS[T.MARRIED]              0.7617         0.3726         1.5574
# MARITAL_STATUS[T.NOT MARRIED]          0.4952         0.2458         0.9978
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.8619         0.4761         1.5602
# ETHNICITY[T.OTHER]                     0.7949         0.4196         1.5059
# ADMISSION_AGE                          1.0252         1.0162         1.0343
# ELIX_SCORE                             1.0282         0.9712         1.0884
# SOFA                                   1.1930         1.1537         1.2337
# ANNOTATION_CHILD                       1.4519         1.1113         1.8970
# ANNOTATION_SPOUSE                      0.9056         0.6599         1.2429
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0115
# MARITAL_STATUS[T.MARRIED]           0.4558
# MARITAL_STATUS[T.NOT MARRIED]       0.0493
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.6236
# ETHNICITY[T.OTHER]                  0.4813
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.3392
# SOFA                                0.0000
# ANNOTATION_CHILD                    0.0063
# ANNOTATION_SPOUSE                   0.5394

# %% [markdown]
# ## Caregiver[Categorical]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER'))"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.563747
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0561         0.0221         0.1427
# SEX[T.F]                               0.7226         0.5622         0.9289
# MARITAL_STATUS[T.MARRIED]              0.7617         0.3726         1.5575
# MARITAL_STATUS[T.NOT MARRIED]          0.4945         0.2454         0.9965
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.8621         0.4764         1.5601
# ETHNICITY[T.OTHER]                     0.7944         0.4194         1.5047
# ANNOTATION[T.BOTH]                     1.3014         0.8684         1.9502
# ANNOTATION[T.CHILD]                    1.4835         1.0628         2.0709
# ANNOTATION[T.SPOUSE]                   0.9263         0.6341         1.3530
# ADMISSION_AGE                          1.0251         1.0161         1.0342
# ELIX_SCORE                             1.0282         0.9713         1.0885
# SOFA                                   1.1932         1.1538         1.2339
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0112
# MARITAL_STATUS[T.MARRIED]           0.4558
# MARITAL_STATUS[T.NOT MARRIED]       0.0489
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.6239
# ETHNICITY[T.OTHER]                  0.4801
# ANNOTATION[T.BOTH]                  0.2019
# ANNOTATION[T.CHILD]                 0.0205
# ANNOTATION[T.SPOUSE]                0.6920
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.3383
# SOFA                                0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.549731
#          Iterations 6
#                                    odds ratio  95% CI, lower  95% CI, upper  \
# Intercept                              0.0381         0.0147         0.0991
# SEX[T.F]                               0.7080         0.5486         0.9137
# MARITAL_STATUS[T.MARRIED]              0.7953         0.3872         1.6335
# MARITAL_STATUS[T.NOT MARRIED]          0.4677         0.2311         0.9465
# ETHNICITY[T.(NON-HISPANIC) WHITE]      0.8357         0.4570         1.5282
# ETHNICITY[T.OTHER]                     0.8014         0.4185         1.5346
# ANNOTATION[T.BOTH]                     1.0279         0.6763         1.5624
# ANNOTATION[T.CHILD]                    1.3040         0.9270         1.8343
# ANNOTATION[T.SPOUSE]                   0.7548         0.5097         1.1177
# ADMISSION_AGE                          1.0238         1.0147         1.0330
# ELIX_SCORE                             1.0327         0.9746         1.0942
# SOFA                                   1.1855         1.1460         1.2263
# IDENTIFIED_CONV_GOC                    2.4579         1.8364         3.2897
#
#                                    p-value
# Intercept                           0.0000
# SEX[T.F]                            0.0080
# MARITAL_STATUS[T.MARRIED]           0.5328
# MARITAL_STATUS[T.NOT MARRIED]       0.0346
# ETHNICITY[T.(NON-HISPANIC) WHITE]   0.5599
# ETHNICITY[T.OTHER]                  0.5042
# ANNOTATION[T.BOTH]                  0.8974
# ANNOTATION[T.CHILD]                 0.1273
# ANNOTATION[T.SPOUSE]                0.1602
# ADMISSION_AGE                       0.0000
# ELIX_SCORE                          0.2759
# SOFA                                0.0000
# IDENTIFIED_CONV_GOC                 0.0000

# %% [markdown]
# ## Caregiver[Categorical] + GOC Documentation[Binary] + Caregiver[Categorical]$\times$GOC Documentation[Binary]

# %%
formula = "MORTALITY_3MO_FROM_HADM_ADMIT ~ "\
    "C(SEX, Treatment(reference='M')) + "\
    "C(MARITAL_STATUS, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "C(ETHNICITY, Treatment(reference='UNKNOWN/NOT SPECIFIED')) + "\
    "ADMISSION_AGE + "\
    "ELIX_SCORE + "\
    "SOFA + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) + "\
    "IDENTIFIED_CONV_GOC + "\
    "C(ANNOTATION, Treatment(reference='NEITHER')) * IDENTIFIED_CONV_GOC"

model = run_logit(formula, df)

format_logit_results(model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.549193
#          Iterations 6
#                                           odds ratio  95% CI, lower  \
# Intercept                                     0.0373         0.0139
# SEX[T.F]                                      0.7064         0.5469
# MARITAL_STATUS[T.MARRIED]                     0.7801         0.3780
# MARITAL_STATUS[T.NOT MARRIED]                 0.4528         0.2225
# ETHNICITY[T.(NON-HISPANIC) WHITE]             0.8373         0.4567
# ETHNICITY[T.OTHER]                            0.8104         0.4218
# ANNOTATION[T.BOTH]                            1.2259         0.5300
# ANNOTATION[T.CHILD]                           1.1940         0.6231
# ANNOTATION[T.SPOUSE]                          1.0093         0.5089
# ADMISSION_AGE                                 1.0236         1.0145
# ELIX_SCORE                                    1.0326         0.9745
# SOFA                                          1.1862         1.1466
# IDENTIFIED_CONV_GOC                           2.6719         1.7104
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC        0.7903         0.3142
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC       1.1041         0.5288
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC      0.6773         0.3105
#
#                                           95% CI, upper  p-value
# Intercept                                        0.1005   0.0000
# SEX[T.F]                                         0.9123   0.0077
# MARITAL_STATUS[T.MARRIED]                        1.6099   0.5017
# MARITAL_STATUS[T.NOT MARRIED]                    0.9212   0.0288
# ETHNICITY[T.(NON-HISPANIC) WHITE]                1.5352   0.5660
# ETHNICITY[T.OTHER]                               1.5570   0.5281
# ANNOTATION[T.BOTH]                               2.8359   0.6340
# ANNOTATION[T.CHILD]                              2.2880   0.5931
# ANNOTATION[T.SPOUSE]                             2.0020   0.9788
# ADMISSION_AGE                                    1.0328   0.0000
# ELIX_SCORE                                       1.0941   0.2773
# SOFA                                             1.2271   0.0000
# IDENTIFIED_CONV_GOC                              4.1738   0.0000
# ANNOTATION[T.BOTH]:IDENTIFIED_CONV_GOC           1.9881   0.6171
# ANNOTATION[T.CHILD]:IDENTIFIED_CONV_GOC          2.3054   0.7921
# ANNOTATION[T.SPOUSE]:IDENTIFIED_CONV_GOC         1.4774   0.3275
