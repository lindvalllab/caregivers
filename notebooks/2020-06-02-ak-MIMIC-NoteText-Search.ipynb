# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/mimic-iii/NOTEEVENTS.csv', usecols=['ROW_ID', 'SUBJECT_ID', 'TEXT'])

# %%
so_col = df['TEXT'].str.contains('exwife')

print(so_col.sum())
print(df[so_col]['TEXT'].iloc[0])
# Out:
# 27
# Admission Date:  [**2186-11-17**]       Discharge Date:  [**2186-11-24**]
#
# Date of Birth:   [**2114-3-14**]       Sex:  M
#
# Service:  MICU [**Location (un) **]
#
# HISTORY OF PRESENT ILLNESS: [**Last Name (un) 24527**] [**Known lastname 97946**] is a
# seventy-two-year-old man with a past medical history
# significant for ischemic heart disease, pulmonary
# hypertension, secondary to emphysema, recently admitted for
# exacerbation of congestive heart failure with hypoxia and
# fluid overload. The patient was re-admitted to [**Hospital1 346**] on [**2186-11-17**], for increasing edema
# and shortness of breath. The patient also had two days of
# weakness. The patient was seen on the night prior to
# admission by a visiting nurse who noted hypotension with a
# blood pressure of 90/60, a dry mouth, little edema and dry
# lungs. The patient presented to the Emergency Department on
# the following morning for evaluation. The patient was
# ...
